# %%
import pandas as pd
from ftplib import FTP
from datetime import datetime

# %%
def get_data_list():
    """
    Input: None
    Output: List of all files available on STMTA FTP Server
    """    
    ftp = FTP('avl-data.sfmta.com') 
    ftp.login()
    ftp.cwd('AVL_DATA/AVL_RAW/')
    files = []
    ftp.retrlines('NLST', files.append)
    
    return files

# %%
a = get_data_list()
a
# Out:
# ['lookUpBlockIDToBlockNumNam.csv',
#  'lookUpSignUpPeriods.csv',
#  'Pre_08152012',
#  'read_me.txt',
#  'sfmtaAVL04042012_04112012.zip',
#  'sfmtaAVLRawData01012013.csv',
#  'sfmtaAVLRawData01012014.csv',
#  'sfmtaAVLRawData01012015.csv',
#  'sfmtaAVLRawData01022013.csv',
#  'sfmtaAVLRawData01022014.csv',
#  'sfmtaAVLRawData01022015.csv',
#  'sfmtaAVLRawData01032013.csv',
#  'sfmtaAVLRawData01032014.csv',
#  'sfmtaAVLRawData01032015.csv',
#  'sfmtaAVLRawData01032016.csv',
#  'sfmtaAVLRawData01042013.csv',
#  'sfmtaAVLRawData01042014.csv',
#  'sfmtaAVLRawData01042015.csv',
#  'sfmtaAVLRawData01042016.csv',
#  'sfmtaAVLRawData01052013.csv',
#  'sfmtaAVLRawData01052014.csv',
#  'sfmtaAVLRawData01052015.csv',
#  'sfmtaAVLRawData01052016.csv',
#  'sfmtaAVLRawData01062013.csv',
#  'sfmtaAVLRawData01062014.csv',
#  'sfmtaAVLRawData01062015.csv',
#  'sfmtaAVLRawData01062016.csv',
#  'sfmtaAVLRawData01072013.csv',
#  'sfmtaAVLRawData01072014.csv',
#  'sfmtaAVLRawData01072015.csv',
#  'sfmtaAVLRawData01072016.csv',
#  'sfmtaAVLRawData01082013.csv',
#  'sfmtaAVLRawData01082014.csv',
#  'sfmtaAVLRawData01082015.csv',
#  'sfmtaAVLRawData01082016.csv',
#  'sfmtaAVLRawData01092013.csv',
#  'sfmtaAVLRawData01092014.csv',
#  'sfmtaAVLRawData01092015.csv',
#  'sfmtaAVLRawData01092016.csv',
#  'sfmtaAVLRawData01102013.csv',
#  'sfmtaAVLRawData01102014.csv',
#  'sfmtaAVLRawData01102015.csv',
#  'sfmtaAVLRawData01102016.csv',
#  'sfmtaAVLRawData01112013.csv',
#  'sfmtaAVLRawData01112014.csv',
#  'sfmtaAVLRawData01112015.csv',
#  'sfmtaAVLRawData01112016.csv',
#  'sfmtaAVLRawData01122013.csv',
#  'sfmtaAVLRawData01122014.csv',
#  'sfmtaAVLRawData01122015.csv',
#  'sfmtaAVLRawData01122016.csv',
#  'sfmtaAVLRawData01132013.csv',
#  'sfmtaAVLRawData01132014.csv',
#  'sfmtaAVLRawData01132015.csv',
#  'sfmtaAVLRawData01132016.csv',
#  'sfmtaAVLRawData01142013.csv',
#  'sfmtaAVLRawData01142014.csv',
#  'sfmtaAVLRawData01142015.csv',
#  'sfmtaAVLRawData01142016.csv',
#  'sfmtaAVLRawData01152013.csv',
#  'sfmtaAVLRawData01152014.csv',
#  'sfmtaAVLRawData01152015.csv',
#  'sfmtaAVLRawData01152016.csv',
#  'sfmtaAVLRawData01162013.csv',
#  'sfmtaAVLRawData01162014.csv',
#  'sfmtaAVLRawData01162015.csv',
#  'sfmtaAVLRawData01162016.csv',
#  'sfmtaAVLRawData01172013.csv',
#  'sfmtaAVLRawData01172014.csv',
#  'sfmtaAVLRawData01172015.csv',
#  'sfmtaAVLRawData01172016.csv',
#  'sfmtaAVLRawData01182013.csv',
#  'sfmtaAVLRawData01182014.csv',
#  'sfmtaAVLRawData01182015.csv',
#  'sfmtaAVLRawData01182016.csv',
#  'sfmtaAVLRawData01192013.csv',
#  'sfmtaAVLRawData01192014.csv',
#  'sfmtaAVLRawData01192015.csv',
#  'sfmtaAVLRawData01192016.csv',
#  'sfmtaAVLRawData01202013.csv',
#  'sfmtaAVLRawData01202014.csv',
#  'sfmtaAVLRawData01202015.csv',
#  'sfmtaAVLRawData01202016.csv',
#  'sfmtaAVLRawData01212013.csv',
#  'sfmtaAVLRawData01212014.csv',
#  'sfmtaAVLRawData01212015.csv',
#  'sfmtaAVLRawData01212016.csv',
#  'sfmtaAVLRawData01222013.csv',
#  'sfmtaAVLRawData01222014.csv',
#  'sfmtaAVLRawData01222015.csv',
#  'sfmtaAVLRawData01222016.csv',
#  'sfmtaAVLRawData01232013.csv',
#  'sfmtaAVLRawData01232014.csv',
#  'sfmtaAVLRawData01232015.csv',
#  'sfmtaAVLRawData01232016.csv',
#  'sfmtaAVLRawData01242013.csv',
#  'sfmtaAVLRawData01242014.csv',
#  'sfmtaAVLRawData01242015.csv',
#  'sfmtaAVLRawData01242016.csv',
#  'sfmtaAVLRawData01252013.csv',
#  'sfmtaAVLRawData01252014.csv',
#  'sfmtaAVLRawData01252015.csv',
#  'sfmtaAVLRawData01252016.csv',
#  'sfmtaAVLRawData01262013.csv',
#  'sfmtaAVLRawData01262014.csv',
#  'sfmtaAVLRawData01262015.csv',
#  'sfmtaAVLRawData01262016.csv',
#  'sfmtaAVLRawData01272013.csv',
#  'sfmtaAVLRawData01272014.csv',
#  'sfmtaAVLRawData01272015.csv',
#  'sfmtaAVLRawData01272016.csv',
#  'sfmtaAVLRawData01282013.csv',
#  'sfmtaAVLRawData01282014.csv',
#  'sfmtaAVLRawData01282015.csv',
#  'sfmtaAVLRawData01282016.csv',
#  'sfmtaAVLRawData01292013.csv',
#  'sfmtaAVLRawData01292014.csv',
#  'sfmtaAVLRawData01292015.csv',
#  'sfmtaAVLRawData01292016.csv',
#  'sfmtaAVLRawData01302013.csv',
#  'sfmtaAVLRawData01302014.csv',
#  'sfmtaAVLRawData01302015.csv',
#  'sfmtaAVLRawData01302016.csv',
#  'sfmtaAVLRawData01312013.csv',
#  'sfmtaAVLRawData01312015.csv',
#  'sfmtaAVLRawData01312016.csv',
#  'sfmtaAVLRawData02012013.csv',
#  'sfmtaAVLRawData02012014.csv',
#  'sfmtaAVLRawData02012015.csv',
#  'sfmtaAVLRawData02012016.csv',
#  'sfmtaAVLRawData02022013.csv',
#  'sfmtaAVLRawData02022014.csv',
#  'sfmtaAVLRawData02022015.csv',
#  'sfmtaAVLRawData02022016.csv',
#  'sfmtaAVLRawData02032013.csv',
#  'sfmtaAVLRawData02032014.csv',
#  'sfmtaAVLRawData02032016.csv',
#  'sfmtaAVLRawData02042013.csv',
#  'sfmtaAVLRawData02042014.csv',
#  'sfmtaAVLRawData02042015.csv',
#  'sfmtaAVLRawData02042016.csv',
#  'sfmtaAVLRawData02052013.csv',
#  'sfmtaAVLRawData02052014.csv',
#  'sfmtaAVLRawData02052015.csv',
#  'sfmtaAVLRawData02052016.csv',
#  'sfmtaAVLRawData02062013.csv',
#  'sfmtaAVLRawData02062014.csv',
#  'sfmtaAVLRawData02062015.csv',
#  'sfmtaAVLRawData02062016.csv',
#  'sfmtaAVLRawData02072013.csv',
#  'sfmtaAVLRawData02072014.csv',
#  'sfmtaAVLRawData02072015.csv',
#  'sfmtaAVLRawData02072016.csv',
#  'sfmtaAVLRawData02082013.csv',
#  'sfmtaAVLRawData02082014.csv',
#  'sfmtaAVLRawData02082015.csv',
#  'sfmtaAVLRawData02082016.csv',
#  'sfmtaAVLRawData02092013.csv',
#  'sfmtaAVLRawData02092014.csv',
#  'sfmtaAVLRawData02092015.csv',
#  'sfmtaAVLRawData02092016.csv',
#  'sfmtaAVLRawData02102013.csv',
#  'sfmtaAVLRawData02102014.csv',
#  'sfmtaAVLRawData02102015.csv',
#  'sfmtaAVLRawData02102016.csv',
#  'sfmtaAVLRawData02112013.csv',
#  'sfmtaAVLRawData02112014.csv',
#  'sfmtaAVLRawData02112015.csv',
#  'sfmtaAVLRawData02112016.csv',
#  'sfmtaAVLRawData02122013.csv',
#  'sfmtaAVLRawData02122014.csv',
#  'sfmtaAVLRawData02122015.csv',
#  'sfmtaAVLRawData02122016.csv',
#  'sfmtaAVLRawData02132013.csv',
#  'sfmtaAVLRawData02132014.csv',
#  'sfmtaAVLRawData02132015.csv',
#  'sfmtaAVLRawData02132016.csv',
#  'sfmtaAVLRawData02142013.csv',
#  'sfmtaAVLRawData02142014.csv',
#  'sfmtaAVLRawData02142015.csv',
#  'sfmtaAVLRawData02142016.csv',
#  'sfmtaAVLRawData02152013.csv',
#  'sfmtaAVLRawData02152014.csv',
#  'sfmtaAVLRawData02152015.csv',
#  'sfmtaAVLRawData02152016.csv',
#  'sfmtaAVLRawData02162013.csv',
#  'sfmtaAVLRawData02162014.csv',
#  'sfmtaAVLRawData02162015.csv',
#  'sfmtaAVLRawData02162016.csv',
#  'sfmtaAVLRawData02172013.csv',
#  'sfmtaAVLRawData02172014.csv',
#  'sfmtaAVLRawData02172015.csv',
#  'sfmtaAVLRawData02172016.csv',
#  'sfmtaAVLRawData02182013.csv',
#  'sfmtaAVLRawData02182014.csv',
#  'sfmtaAVLRawData02182015.csv',
#  'sfmtaAVLRawData02182016.csv',
#  'sfmtaAVLRawData02192013.csv',
#  'sfmtaAVLRawData02192014.csv',
#  'sfmtaAVLRawData02192015.csv',
#  'sfmtaAVLRawData02192016.csv',
#  'sfmtaAVLRawData02202013.csv',
#  'sfmtaAVLRawData02202014.csv',
#  'sfmtaAVLRawData02202015.csv',
#  'sfmtaAVLRawData02202016.csv',
#  'sfmtaAVLRawData02212013.csv',
#  'sfmtaAVLRawData02212014.csv',
#  'sfmtaAVLRawData02212015.csv',
#  'sfmtaAVLRawData02212016.csv',
#  'sfmtaAVLRawData02222013.csv',
#  'sfmtaAVLRawData02222014.csv',
#  'sfmtaAVLRawData02222015.csv',
#  'sfmtaAVLRawData02222016.csv',
#  'sfmtaAVLRawData02232013.csv',
#  'sfmtaAVLRawData02232014.csv',
#  'sfmtaAVLRawData02232015.csv',
#  'sfmtaAVLRawData02232016.csv',
#  'sfmtaAVLRawData02242013.csv',
#  'sfmtaAVLRawData02242014.csv',
#  'sfmtaAVLRawData02242016.csv',
#  'sfmtaAVLRawData02252013.csv',
#  'sfmtaAVLRawData02252014.csv',
#  'sfmtaAVLRawData02252015.csv',
#  'sfmtaAVLRawData02252016.csv',
#  'sfmtaAVLRawData02262013.csv',
#  'sfmtaAVLRawData02262014.csv',
#  'sfmtaAVLRawData02262015.csv',
#  'sfmtaAVLRawData02262016.csv',
#  'sfmtaAVLRawData02272013.csv',
#  'sfmtaAVLRawData02272014.csv',
#  'sfmtaAVLRawData02272015.csv',
#  'sfmtaAVLRawData02272016.csv',
#  'sfmtaAVLRawData02282013.csv',
#  'sfmtaAVLRawData02282014.csv',
#  'sfmtaAVLRawData02282015.csv',
#  'sfmtaAVLRawData02282016.csv',
#  'sfmtaAVLRawData02292016.csv',
#  'sfmtaAVLRawData03012013.csv',
#  'sfmtaAVLRawData03012014.csv',
#  'sfmtaAVLRawData03012015.csv',
#  'sfmtaAVLRawData03012016.csv',
#  'sfmtaAVLRawData03022013.csv',
#  'sfmtaAVLRawData03022014.csv',
#  'sfmtaAVLRawData03022015.csv',
#  'sfmtaAVLRawData03022016.csv',
#  'sfmtaAVLRawData03032013.csv',
#  'sfmtaAVLRawData03032014.csv',
#  'sfmtaAVLRawData03032015.csv',
#  'sfmtaAVLRawData03032016.csv',
#  'sfmtaAVLRawData03042013.csv',
#  'sfmtaAVLRawData03042014.csv',
#  'sfmtaAVLRawData03042015.csv',
#  'sfmtaAVLRawData03042016.csv',
#  'sfmtaAVLRawData03052013.csv',
#  'sfmtaAVLRawData03052014.csv',
#  'sfmtaAVLRawData03052015.csv',
#  'sfmtaAVLRawData03052016.csv',
#  'sfmtaAVLRawData03062013.csv',
#  'sfmtaAVLRawData03062014.csv',
#  'sfmtaAVLRawData03062015.csv',
#  'sfmtaAVLRawData03062016.csv',
#  'sfmtaAVLRawData03072013.csv',
#  'sfmtaAVLRawData03072014.csv',
#  'sfmtaAVLRawData03072015.csv',
#  'sfmtaAVLRawData03072016.csv',
#  'sfmtaAVLRawData03082013.csv',
#  'sfmtaAVLRawData03082014.csv',
#  'sfmtaAVLRawData03082015.csv',
#  'sfmtaAVLRawData03082016.csv',
#  'sfmtaAVLRawData03092013.csv',
#  'sfmtaAVLRawData03092014.csv',
#  'sfmtaAVLRawData03092015.csv',
#  'sfmtaAVLRawData03092016.csv',
#  'sfmtaAVLRawData03102013.csv',
#  'sfmtaAVLRawData03102014.csv',
#  'sfmtaAVLRawData03102015.csv',
#  'sfmtaAVLRawData03102016.csv',
#  'sfmtaAVLRawData03112013.csv',
#  'sfmtaAVLRawData03112014.csv',
#  'sfmtaAVLRawData03112015.csv',
#  'sfmtaAVLRawData03112016.csv',
#  'sfmtaAVLRawData03122013.csv',
#  'sfmtaAVLRawData03122014.csv',
#  'sfmtaAVLRawData03122015.csv',
#  'sfmtaAVLRawData03122016.csv',
#  'sfmtaAVLRawData03132013.csv',
#  'sfmtaAVLRawData03132014.csv',
#  'sfmtaAVLRawData03132015.csv',
#  'sfmtaAVLRawData03132016.csv',
#  'sfmtaAVLRawData03142013.csv',
#  'sfmtaAVLRawData03142014.csv',
#  'sfmtaAVLRawData03142015.csv',
#  'sfmtaAVLRawData03142016.csv',
#  'sfmtaAVLRawData03152013.csv',
#  'sfmtaAVLRawData03152015.csv',
#  'sfmtaAVLRawData03152016.csv',
#  'sfmtaAVLRawData03162013.csv',
#  'sfmtaAVLRawData03162014.csv',
#  'sfmtaAVLRawData03162015.csv',
#  'sfmtaAVLRawData03162016.csv',
#  'sfmtaAVLRawData03172013.csv',
#  'sfmtaAVLRawData03172014.csv',
#  'sfmtaAVLRawData03172015.csv',
#  'sfmtaAVLRawData03172016.csv',
#  'sfmtaAVLRawData03182013.csv',
#  'sfmtaAVLRawData03182014.csv',
#  'sfmtaAVLRawData03182015.csv',
#  'sfmtaAVLRawData03182016.csv',
#  'sfmtaAVLRawData03192013.csv',
#  'sfmtaAVLRawData03192014.csv',
#  'sfmtaAVLRawData03192015.csv',
#  'sfmtaAVLRawData03192016.csv',
#  'sfmtaAVLRawData03202013.csv',
#  'sfmtaAVLRawData03202014.csv',
#  'sfmtaAVLRawData03202015.csv',
#  'sfmtaAVLRawData03202016.csv',
#  'sfmtaAVLRawData03212013.csv',
#  'sfmtaAVLRawData03212014.csv',
#  'sfmtaAVLRawData03212015.csv',
#  'sfmtaAVLRawData03212016.csv',
#  'sfmtaAVLRawData03222013.csv',
#  'sfmtaAVLRawData03222014.csv',
#  'sfmtaAVLRawData03222016.csv',
#  'sfmtaAVLRawData03232013.csv',
#  'sfmtaAVLRawData03232014.csv',
#  'sfmtaAVLRawData03232015.csv',
#  'sfmtaAVLRawData03232016.csv',
#  'sfmtaAVLRawData03242013.csv',
#  'sfmtaAVLRawData03242014.csv',
#  'sfmtaAVLRawData03242015.csv',
#  'sfmtaAVLRawData03242016.csv',
#  'sfmtaAVLRawData03252013.csv',
#  'sfmtaAVLRawData03252014.csv',
#  'sfmtaAVLRawData03252015.csv',
#  'sfmtaAVLRawData03252016.csv',
#  'sfmtaAVLRawData03262013.csv',
#  'sfmtaAVLRawData03262014.csv',
#  'sfmtaAVLRawData03262015.csv',
#  'sfmtaAVLRawData03262016.csv',
#  'sfmtaAVLRawData03272013.csv',
#  'sfmtaAVLRawData03272014.csv',
#  'sfmtaAVLRawData03272015.csv',
#  'sfmtaAVLRawData03272016.csv',
#  'sfmtaAVLRawData03282013.csv',
#  'sfmtaAVLRawData03282014.csv',
#  'sfmtaAVLRawData03282015.csv',
#  'sfmtaAVLRawData03282016.csv',
#  'sfmtaAVLRawData03292013.csv',
#  'sfmtaAVLRawData03292014.csv',
#  'sfmtaAVLRawData03292015.csv',
#  'sfmtaAVLRawData03292016.csv',
#  'sfmtaAVLRawData03302013.csv',
#  'sfmtaAVLRawData03302014.csv',
#  'sfmtaAVLRawData03302015.csv',
#  'sfmtaAVLRawData03302016.csv',
#  'sfmtaAVLRawData03312013.csv',
#  'sfmtaAVLRawData03312014.csv',
#  'sfmtaAVLRawData03312015.csv',
#  'sfmtaAVLRawData03312016.csv',
#  'sfmtaAVLRawData04012013.csv',
#  'sfmtaAVLRawData04012014.csv',
#  'sfmtaAVLRawData04012015.csv',
#  'sfmtaAVLRawData04012016.csv',
#  'sfmtaAVLRawData04022013.csv',
#  'sfmtaAVLRawData04022014.csv',
#  'sfmtaAVLRawData04022015.csv',
#  'sfmtaAVLRawData04022016.csv',
#  'sfmtaAVLRawData04032013.csv',
#  'sfmtaAVLRawData04032014.csv',
#  'sfmtaAVLRawData04032016.csv',
#  'sfmtaAVLRawData04042013.csv',
#  'sfmtaAVLRawData04042014.csv',
#  'sfmtaAVLRawData04042015.csv',
#  'sfmtaAVLRawData04042016.csv',
#  'sfmtaAVLRawData04052013.csv',
#  'sfmtaAVLRawData04052014.csv',
#  'sfmtaAVLRawData04052015.csv',
#  'sfmtaAVLRawData04052016.csv',
#  'sfmtaAVLRawData04062013.csv',
#  'sfmtaAVLRawData04062014.csv',
#  'sfmtaAVLRawData04062015.csv',
#  'sfmtaAVLRawData04062016.csv',
#  'sfmtaAVLRawData04072013.csv',
#  'sfmtaAVLRawData04072014.csv',
#  'sfmtaAVLRawData04072015.csv',
#  'sfmtaAVLRawData04072016.csv',
#  'sfmtaAVLRawData04082013.csv',
#  'sfmtaAVLRawData04082014.csv',
#  'sfmtaAVLRawData04082015.csv',
#  'sfmtaAVLRawData04082016.csv',
#  'sfmtaAVLRawData04092013.csv',
#  'sfmtaAVLRawData04092014.csv',
#  'sfmtaAVLRawData04092015.csv',
#  'sfmtaAVLRawData04092016.csv',
#  'sfmtaAVLRawData04102013.csv',
#  'sfmtaAVLRawData04102014.csv',
#  'sfmtaAVLRawData04102015.csv',
#  'sfmtaAVLRawData04102016.csv',
#  'sfmtaAVLRawData04112013.csv',
#  'sfmtaAVLRawData04112014.csv',
#  'sfmtaAVLRawData04112015.csv',
#  'sfmtaAVLRawData04112016.csv',
#  'sfmtaAVLRawData04122013.csv',
#  'sfmtaAVLRawData04122014.csv',
#  'sfmtaAVLRawData04122015.csv',
#  'sfmtaAVLRawData04122016.csv',
#  'sfmtaAVLRawData04132013.csv',
#  'sfmtaAVLRawData04132014.csv',
#  'sfmtaAVLRawData04132015.csv',
#  'sfmtaAVLRawData04132016.csv',
#  'sfmtaAVLRawData04142013.csv',
#  'sfmtaAVLRawData04142014.csv',
#  'sfmtaAVLRawData04142015.csv',
#  'sfmtaAVLRawData04142016.csv',
#  'sfmtaAVLRawData04152013.csv',
#  'sfmtaAVLRawData04152014.csv',
#  'sfmtaAVLRawData04152015.csv',
#  'sfmtaAVLRawData04152016.csv',
#  'sfmtaAVLRawData04162013.csv',
#  'sfmtaAVLRawData04162014.csv',
#  'sfmtaAVLRawData04162015.csv',
#  'sfmtaAVLRawData04162016.csv',
#  'sfmtaAVLRawData04172013.csv',
#  'sfmtaAVLRawData04172014.csv',
#  'sfmtaAVLRawData04172015.csv',
#  'sfmtaAVLRawData04172016.csv',
#  'sfmtaAVLRawData04182013.csv',
#  'sfmtaAVLRawData04182014.csv',
#  'sfmtaAVLRawData04182015.csv',
#  'sfmtaAVLRawData04192013.csv',
#  'sfmtaAVLRawData04192014.csv',
#  'sfmtaAVLRawData04192015.csv',
#  'sfmtaAVLRawData04192016.csv',
#  'sfmtaAVLRawData04202013.csv',
#  'sfmtaAVLRawData04202014.csv',
#  'sfmtaAVLRawData04202015.csv',
#  'sfmtaAVLRawData04202016.csv',
#  'sfmtaAVLRawData04212013.csv',
#  'sfmtaAVLRawData04212014.csv',
#  'sfmtaAVLRawData04212015.csv',
#  'sfmtaAVLRawData04212016.csv',
#  'sfmtaAVLRawData04222013.csv',
#  'sfmtaAVLRawData04222014.csv',
#  'sfmtaAVLRawData04222015.csv',
#  'sfmtaAVLRawData04222016.csv',
#  'sfmtaAVLRawData04232014.csv',
#  'sfmtaAVLRawData04232015.csv',
#  'sfmtaAVLRawData04232016.csv',
#  'sfmtaAVLRawData04242013.csv',
#  'sfmtaAVLRawData04242014.csv',
#  'sfmtaAVLRawData04242015.csv',
#  'sfmtaAVLRawData04242016.csv',
#  'sfmtaAVLRawData04252013.csv',
#  'sfmtaAVLRawData04252014.csv',
#  'sfmtaAVLRawData04252015.csv',
#  'sfmtaAVLRawData04252016.csv',
#  'sfmtaAVLRawData04262013.csv',
#  'sfmtaAVLRawData04262014.csv',
#  'sfmtaAVLRawData04262015.csv',
#  'sfmtaAVLRawData04262016.csv',
#  'sfmtaAVLRawData04272013.csv',
#  'sfmtaAVLRawData04272014.csv',
#  'sfmtaAVLRawData04272015.csv',
#  'sfmtaAVLRawData04272016.csv',
#  'sfmtaAVLRawData04282013.csv',
#  'sfmtaAVLRawData04282014.csv',
#  'sfmtaAVLRawData04282015.csv',
#  'sfmtaAVLRawData04282016.csv',
#  'sfmtaAVLRawData04292013.csv',
#  'sfmtaAVLRawData04292014.csv',
#  'sfmtaAVLRawData04292015.csv',
#  'sfmtaAVLRawData04292016.csv',
#  'sfmtaAVLRawData04302013.csv',
#  'sfmtaAVLRawData04302014.csv',
#  'sfmtaAVLRawData04302015.csv',
#  'sfmtaAVLRawData04302016.csv',
#  'sfmtaAVLRawData05012013.csv',
#  'sfmtaAVLRawData05012014.csv',
#  'sfmtaAVLRawData05012015.csv',
#  'sfmtaAVLRawData05012016.csv',
#  'sfmtaAVLRawData05022013.csv',
#  'sfmtaAVLRawData05022014.csv',
#  'sfmtaAVLRawData05022015.csv',
#  'sfmtaAVLRawData05022016.csv',
#  'sfmtaAVLRawData05032013.csv',
#  'sfmtaAVLRawData05032015.csv',
#  'sfmtaAVLRawData05032016.csv',
#  'sfmtaAVLRawData05042013.csv',
#  'sfmtaAVLRawData05042014.csv',
#  'sfmtaAVLRawData05042015.csv',
#  'sfmtaAVLRawData05042016.csv',
#  'sfmtaAVLRawData05052013.csv',
#  'sfmtaAVLRawData05052014.csv',
#  'sfmtaAVLRawData05052015.csv',
#  'sfmtaAVLRawData05052016.csv',
#  'sfmtaAVLRawData05062013.csv',
#  'sfmtaAVLRawData05062014.csv',
#  'sfmtaAVLRawData05062015.csv',
#  'sfmtaAVLRawData05062016.csv',
#  'sfmtaAVLRawData05072013.csv',
#  'sfmtaAVLRawData05072014.csv',
#  'sfmtaAVLRawData05072015.csv',
#  'sfmtaAVLRawData05072016.csv',
#  'sfmtaAVLRawData05082013.csv',
#  'sfmtaAVLRawData05082014.csv',
#  'sfmtaAVLRawData05082015.csv',
#  'sfmtaAVLRawData05082016.csv',
#  'sfmtaAVLRawData05092013.csv',
#  'sfmtaAVLRawData05092014.csv',
#  'sfmtaAVLRawData05092015.csv',
#  'sfmtaAVLRawData05092016.csv',
#  'sfmtaAVLRawData05102013.csv',
#  'sfmtaAVLRawData05102014.csv',
#  'sfmtaAVLRawData05102015.csv',
#  'sfmtaAVLRawData05102016.csv',
#  'sfmtaAVLRawData05112013.csv',
#  'sfmtaAVLRawData05112014.csv',
#  'sfmtaAVLRawData05112015.csv',
#  'sfmtaAVLRawData05112016.csv',
#  'sfmtaAVLRawData05122014.csv',
#  'sfmtaAVLRawData05122015.csv',
#  'sfmtaAVLRawData05122016.csv',
#  'sfmtaAVLRawData05132013.csv',
#  'sfmtaAVLRawData05132014.csv',
#  'sfmtaAVLRawData05132015.csv',
#  'sfmtaAVLRawData05132016.csv',
#  'sfmtaAVLRawData05142013.csv',
#  'sfmtaAVLRawData05142014.csv',
#  'sfmtaAVLRawData05142015.csv',
#  'sfmtaAVLRawData05142016.csv',
#  'sfmtaAVLRawData05152013.csv',
#  'sfmtaAVLRawData05152014.csv',
#  'sfmtaAVLRawData05152015.csv',
#  'sfmtaAVLRawData05152016.csv',
#  'sfmtaAVLRawData05162013.csv',
#  'sfmtaAVLRawData05162014.csv',
#  'sfmtaAVLRawData05162015.csv',
#  'sfmtaAVLRawData05162016.csv',
#  'sfmtaAVLRawData05172013.csv',
#  'sfmtaAVLRawData05172014.csv',
#  'sfmtaAVLRawData05172015.csv',
#  'sfmtaAVLRawData05172016.csv',
#  'sfmtaAVLRawData05182013.csv',
#  'sfmtaAVLRawData05182014.csv',
#  'sfmtaAVLRawData05182015.csv',
#  'sfmtaAVLRawData05182016.csv',
#  'sfmtaAVLRawData05192013.csv',
#  'sfmtaAVLRawData05192014.csv',
#  'sfmtaAVLRawData05192015.csv',
#  'sfmtaAVLRawData05192016.csv',
#  'sfmtaAVLRawData05202013.csv',
#  'sfmtaAVLRawData05202014.csv',
#  'sfmtaAVLRawData05202015.csv',
#  'sfmtaAVLRawData05202016.csv',
#  'sfmtaAVLRawData05212013.csv',
#  'sfmtaAVLRawData05212014.csv',
#  'sfmtaAVLRawData05212015.csv',
#  'sfmtaAVLRawData05212016.csv',
#  'sfmtaAVLRawData05222013.csv',
#  'sfmtaAVLRawData05222014.csv',
#  'sfmtaAVLRawData05222016.csv',
#  'sfmtaAVLRawData05232013.csv',
#  'sfmtaAVLRawData05232014.csv',
#  'sfmtaAVLRawData05232016.csv',
#  'sfmtaAVLRawData05242013.csv',
#  'sfmtaAVLRawData05242014.csv',
#  'sfmtaAVLRawData05242016.csv',
#  'sfmtaAVLRawData05252013.csv',
#  'sfmtaAVLRawData05252014.csv',
#  'sfmtaAVLRawData05252016.csv',
#  'sfmtaAVLRawData05262013.csv',
#  'sfmtaAVLRawData05262014.csv',
#  'sfmtaAVLRawData05262016.csv',
#  'sfmtaAVLRawData05272013.csv',
#  'sfmtaAVLRawData05272014.csv',
#  'sfmtaAVLRawData05272016.csv',
#  'sfmtaAVLRawData05282013.csv',
#  'sfmtaAVLRawData05282014.csv',
#  'sfmtaAVLRawData05282015.csv',
#  'sfmtaAVLRawData05282016.csv',
#  'sfmtaAVLRawData05292013.csv',
#  'sfmtaAVLRawData05292014.csv',
#  'sfmtaAVLRawData05292015.csv',
#  'sfmtaAVLRawData05292016.csv',
#  'sfmtaAVLRawData05302013.csv',
#  'sfmtaAVLRawData05302014.csv',
#  'sfmtaAVLRawData05302015.csv',
#  'sfmtaAVLRawData05302016.csv',
#  'sfmtaAVLRawData05312013.csv',
#  'sfmtaAVLRawData05312014.csv',
#  'sfmtaAVLRawData05312015.csv',
#  'sfmtaAVLRawData05312016.csv',
#  'sfmtaAVLRawData06012013.csv',
#  'sfmtaAVLRawData06012014.csv',
#  'sfmtaAVLRawData06012015.csv',
#  'sfmtaAVLRawData06012016.csv',
#  'sfmtaAVLRawData06022013.csv',
#  'sfmtaAVLRawData06022014.csv',
#  'sfmtaAVLRawData06022015.csv',
#  'sfmtaAVLRawData06022016.csv',
#  'sfmtaAVLRawData06032013.csv',
#  'sfmtaAVLRawData06032014.csv',
#  'sfmtaAVLRawData06032015.csv',
#  'sfmtaAVLRawData06032016.csv',
#  'sfmtaAVLRawData06042013.csv',
#  'sfmtaAVLRawData06042014.csv',
#  'sfmtaAVLRawData06042015.csv',
#  'sfmtaAVLRawData06042016.csv',
#  'sfmtaAVLRawData06052013.csv',
#  'sfmtaAVLRawData06052014.csv',
#  'sfmtaAVLRawData06052015.csv',
#  'sfmtaAVLRawData06052016.csv',
#  'sfmtaAVLRawData06062013.csv',
#  'sfmtaAVLRawData06062014.csv',
#  'sfmtaAVLRawData06062015.csv',
#  'sfmtaAVLRawData06062016.csv',
#  'sfmtaAVLRawData06072013.csv',
#  'sfmtaAVLRawData06072014.csv',
#  'sfmtaAVLRawData06072015.csv',
#  'sfmtaAVLRawData06072016.csv',
#  'sfmtaAVLRawData06082013.csv',
#  'sfmtaAVLRawData06082014.csv',
#  'sfmtaAVLRawData06082015.csv',
#  'sfmtaAVLRawData06082016.csv',
#  'sfmtaAVLRawData06092013.csv',
#  'sfmtaAVLRawData06092014.csv',
#  'sfmtaAVLRawData06092015.csv',
#  'sfmtaAVLRawData06092016.csv',
#  'sfmtaAVLRawData06102013.csv',
#  'sfmtaAVLRawData06102014.csv',
#  'sfmtaAVLRawData06102015.csv',
#  'sfmtaAVLRawData06102016.csv',
#  'sfmtaAVLRawData06112013.csv',
#  'sfmtaAVLRawData06112014.csv',
#  'sfmtaAVLRawData06112015.csv',
#  'sfmtaAVLRawData06112016.csv',
#  'sfmtaAVLRawData06122013.csv',
#  'sfmtaAVLRawData06122014.csv',
#  'sfmtaAVLRawData06122015.csv',
#  'sfmtaAVLRawData06122016.csv',
#  'sfmtaAVLRawData06132013.csv',
#  'sfmtaAVLRawData06132014.csv',
#  'sfmtaAVLRawData06132015.csv',
#  'sfmtaAVLRawData06132016.csv',
#  'sfmtaAVLRawData06142013.csv',
#  'sfmtaAVLRawData06142014.csv',
#  'sfmtaAVLRawData06142015.csv',
#  'sfmtaAVLRawData06142016.csv',
#  'sfmtaAVLRawData06152013.csv',
#  'sfmtaAVLRawData06152014.csv',
#  'sfmtaAVLRawData06152015.csv',
#  'sfmtaAVLRawData06152016.csv',
#  'sfmtaAVLRawData06162013.csv',
#  'sfmtaAVLRawData06162014.csv',
#  'sfmtaAVLRawData06162015.csv',
#  'sfmtaAVLRawData06162016.csv',
#  'sfmtaAVLRawData06172013.csv',
#  'sfmtaAVLRawData06172014.csv',
#  'sfmtaAVLRawData06172015.csv',
#  'sfmtaAVLRawData06172016.csv',
#  'sfmtaAVLRawData06182013.csv',
#  'sfmtaAVLRawData06182014.csv',
#  'sfmtaAVLRawData06182015.csv',
#  'sfmtaAVLRawData06182016.csv',
#  'sfmtaAVLRawData06192013.csv',
#  'sfmtaAVLRawData06192014.csv',
#  'sfmtaAVLRawData06192015.csv',
#  'sfmtaAVLRawData06192016.csv',
#  'sfmtaAVLRawData06202013.csv',
#  'sfmtaAVLRawData06202014.csv',
#  'sfmtaAVLRawData06202015.csv',
#  'sfmtaAVLRawData06202016.csv',
#  'sfmtaAVLRawData06212013.csv',
#  'sfmtaAVLRawData06212014.csv',
#  'sfmtaAVLRawData06212015.csv',
#  'sfmtaAVLRawData06212016.csv',
#  'sfmtaAVLRawData06222013.csv',
#  'sfmtaAVLRawData06222014.csv',
#  'sfmtaAVLRawData06222015.csv',
#  'sfmtaAVLRawData06222016.csv',
#  'sfmtaAVLRawData06232013.csv',
#  'sfmtaAVLRawData06232014.csv',
#  'sfmtaAVLRawData06232015.csv',
#  'sfmtaAVLRawData06232016.csv',
#  'sfmtaAVLRawData06242013.csv',
#  'sfmtaAVLRawData06242014.csv',
#  'sfmtaAVLRawData06242015.csv',
#  'sfmtaAVLRawData06242016.csv',
#  'sfmtaAVLRawData06252013.csv',
#  'sfmtaAVLRawData06252014.csv',
#  'sfmtaAVLRawData06252015.csv',
#  'sfmtaAVLRawData06252016.csv',
#  'sfmtaAVLRawData06262013.csv',
#  'sfmtaAVLRawData06262014.csv',
#  'sfmtaAVLRawData06262015.csv',
#  'sfmtaAVLRawData06262016.csv',
#  'sfmtaAVLRawData06272013.csv',
#  'sfmtaAVLRawData06272014.csv',
#  'sfmtaAVLRawData06272015.csv',
#  'sfmtaAVLRawData06272016.csv',
#  'sfmtaAVLRawData06282013.csv',
#  'sfmtaAVLRawData06282014.csv',
#  'sfmtaAVLRawData06282015.csv',
#  'sfmtaAVLRawData06282016.csv',
#  'sfmtaAVLRawData06292013.csv',
#  'sfmtaAVLRawData06292014.csv',
#  'sfmtaAVLRawData06292015.csv',
#  'sfmtaAVLRawData06292016.csv',
#  'sfmtaAVLRawData06302013.csv',
#  'sfmtaAVLRawData06302014.csv',
#  'sfmtaAVLRawData06302015.csv',
#  'sfmtaAVLRawData06302016.csv',
#  'sfmtaAVLRawData07012013.csv',
#  'sfmtaAVLRawData07012015.csv',
#  'sfmtaAVLRawData07012016.csv',
#  'sfmtaAVLRawData07022013.csv',
#  'sfmtaAVLRawData07022014.csv',
#  'sfmtaAVLRawData07022015.csv',
#  'sfmtaAVLRawData07022016.csv',
#  'sfmtaAVLRawData07032013.csv',
#  'sfmtaAVLRawData07032014.csv',
#  'sfmtaAVLRawData07032015.csv',
#  'sfmtaAVLRawData07032016.csv',
#  'sfmtaAVLRawData07042013.csv',
#  'sfmtaAVLRawData07042014.csv',
#  'sfmtaAVLRawData07042015.csv',
#  'sfmtaAVLRawData07042016.csv',
#  'sfmtaAVLRawData07052013.csv',
#  'sfmtaAVLRawData07052014.csv',
#  'sfmtaAVLRawData07052015.csv',
#  'sfmtaAVLRawData07052016.csv',
#  'sfmtaAVLRawData07062013.csv',
#  'sfmtaAVLRawData07062014.csv',
#  'sfmtaAVLRawData07062015.csv',
#  'sfmtaAVLRawData07062016.csv',
#  'sfmtaAVLRawData07072013.csv',
#  'sfmtaAVLRawData07072014.csv',
#  'sfmtaAVLRawData07072015.csv',
#  'sfmtaAVLRawData07072016.csv',
#  'sfmtaAVLRawData07082013.csv',
#  'sfmtaAVLRawData07082014.csv',
#  'sfmtaAVLRawData07082015.csv',
#  'sfmtaAVLRawData07082016.csv',
#  'sfmtaAVLRawData07092013.csv',
#  'sfmtaAVLRawData07092014.csv',
#  'sfmtaAVLRawData07092015.csv',
#  'sfmtaAVLRawData07092016.csv',
#  'sfmtaAVLRawData07102013.csv',
#  'sfmtaAVLRawData07102014.csv',
#  'sfmtaAVLRawData07102015.csv',
#  'sfmtaAVLRawData07102016.csv',
#  'sfmtaAVLRawData07112013.csv',
#  'sfmtaAVLRawData07112014.csv',
#  'sfmtaAVLRawData07112015.csv',
#  'sfmtaAVLRawData07112016.csv',
#  'sfmtaAVLRawData07122013.csv',
#  'sfmtaAVLRawData07122014.csv',
#  'sfmtaAVLRawData07122015.csv',
#  'sfmtaAVLRawData07122016.csv',
#  'sfmtaAVLRawData07132013.csv',
#  'sfmtaAVLRawData07132014.csv',
#  'sfmtaAVLRawData07132015.csv',
#  'sfmtaAVLRawData07132016.csv',
#  'sfmtaAVLRawData07142013.csv',
#  'sfmtaAVLRawData07142014.csv',
#  'sfmtaAVLRawData07142015.csv',
#  'sfmtaAVLRawData07142016.csv',
#  'sfmtaAVLRawData07152013.csv',
#  'sfmtaAVLRawData07152014.csv',
#  'sfmtaAVLRawData07152015.csv',
#  'sfmtaAVLRawData07152016.csv',
#  'sfmtaAVLRawData07162013.csv',
#  'sfmtaAVLRawData07162014.csv',
#  'sfmtaAVLRawData07162015.csv',
#  'sfmtaAVLRawData07162016.csv',
#  'sfmtaAVLRawData07172013.csv',
#  'sfmtaAVLRawData07172014.csv',
#  'sfmtaAVLRawData07172015.csv',
#  'sfmtaAVLRawData07172016.csv',
#  'sfmtaAVLRawData07182013.csv',
#  'sfmtaAVLRawData07182014.csv',
#  'sfmtaAVLRawData07182015.csv',
#  'sfmtaAVLRawData07182016.csv',
#  'sfmtaAVLRawData07192013.csv',
#  'sfmtaAVLRawData07192014.csv',
#  'sfmtaAVLRawData07192015.csv',
#  'sfmtaAVLRawData07192016.csv',
#  'sfmtaAVLRawData07202013.csv',
#  'sfmtaAVLRawData07202014.csv',
#  'sfmtaAVLRawData07202015.csv',
#  'sfmtaAVLRawData07202016.csv',
#  'sfmtaAVLRawData07212013.csv',
#  'sfmtaAVLRawData07212014.csv',
#  'sfmtaAVLRawData07212015.csv',
#  'sfmtaAVLRawData07212016.csv',
#  'sfmtaAVLRawData07222013.csv',
#  'sfmtaAVLRawData07222014.csv',
#  'sfmtaAVLRawData07222015.csv',
#  'sfmtaAVLRawData07222016.csv',
#  'sfmtaAVLRawData07232013.csv',
#  'sfmtaAVLRawData07232014.csv',
#  'sfmtaAVLRawData07232015.csv',
#  'sfmtaAVLRawData07232016.csv',
#  'sfmtaAVLRawData07242013.csv',
#  'sfmtaAVLRawData07242014.csv',
#  'sfmtaAVLRawData07242015.csv',
#  'sfmtaAVLRawData07242016.csv',
#  'sfmtaAVLRawData07252013.csv',
#  'sfmtaAVLRawData07252014.csv',
#  'sfmtaAVLRawData07252015.csv',
#  'sfmtaAVLRawData07252016.csv',
#  'sfmtaAVLRawData07262013.csv',
#  'sfmtaAVLRawData07262014.csv',
#  'sfmtaAVLRawData07262015.csv',
#  'sfmtaAVLRawData07262016.csv',
#  'sfmtaAVLRawData07272013.csv',
#  'sfmtaAVLRawData07272014.csv',
#  'sfmtaAVLRawData07272015.csv',
#  'sfmtaAVLRawData07272016.csv',
#  'sfmtaAVLRawData07282013.csv',
#  'sfmtaAVLRawData07282014.csv',
#  'sfmtaAVLRawData07282015.csv',
#  'sfmtaAVLRawData07282016.csv',
#  'sfmtaAVLRawData07292013.csv',
#  'sfmtaAVLRawData07292014.csv',
#  'sfmtaAVLRawData07292015.csv',
#  'sfmtaAVLRawData07292016.csv',
#  'sfmtaAVLRawData07302013.csv',
#  'sfmtaAVLRawData07302014.csv',
#  'sfmtaAVLRawData07302015.csv',
#  'sfmtaAVLRawData07302016.csv',
#  'sfmtaAVLRawData07312013.csv',
#  'sfmtaAVLRawData07312014.csv',
#  'sfmtaAVLRawData07312015.csv',
#  'sfmtaAVLRawData07312016.csv',
#  'sfmtaAVLRawData08012013.csv',
#  'sfmtaAVLRawData08012014.csv',
#  'sfmtaAVLRawData08012015.csv',
#  'sfmtaAVLRawData08012016.csv',
#  'sfmtaAVLRawData08022013.csv',
#  'sfmtaAVLRawData08022014.csv',
#  'sfmtaAVLRawData08022015.csv',
#  'sfmtaAVLRawData08022016.csv',
#  'sfmtaAVLRawData08032013.csv',
#  'sfmtaAVLRawData08032014.csv',
#  'sfmtaAVLRawData08032015.csv',
#  'sfmtaAVLRawData08032016.csv',
#  'sfmtaAVLRawData08042013.csv',
#  'sfmtaAVLRawData08042014.csv',
#  'sfmtaAVLRawData08042015.csv',
#  'sfmtaAVLRawData08042016.csv',
#  'sfmtaAVLRawData08052013.csv',
#  'sfmtaAVLRawData08052014.csv',
#  'sfmtaAVLRawData08052015.csv',
#  'sfmtaAVLRawData08052016.csv',
#  'sfmtaAVLRawData08062013.csv',
#  'sfmtaAVLRawData08062014.csv',
#  'sfmtaAVLRawData08062015.csv',
#  'sfmtaAVLRawData08062016.csv',
#  'sfmtaAVLRawData08072013.csv',
#  'sfmtaAVLRawData08072014.csv',
#  'sfmtaAVLRawData08072015.csv',
#  'sfmtaAVLRawData08072016.csv',
#  'sfmtaAVLRawData08082013.csv',
#  'sfmtaAVLRawData08082014.csv',
#  'sfmtaAVLRawData08082015.csv',
#  'sfmtaAVLRawData08082016.csv',
#  'sfmtaAVLRawData08092013.csv',
#  'sfmtaAVLRawData08092014.csv',
#  'sfmtaAVLRawData08092015.csv',
#  'sfmtaAVLRawData08092016.csv',
#  'sfmtaAVLRawData08102013.csv',
#  'sfmtaAVLRawData08102014.csv',
#  'sfmtaAVLRawData08102015.csv',
#  'sfmtaAVLRawData08102016.csv',
#  'sfmtaAVLRawData08112013.csv',
#  'sfmtaAVLRawData08112014.csv',
#  'sfmtaAVLRawData08112015.csv',
#  'sfmtaAVLRawData08112016.csv',
#  'sfmtaAVLRawData08122013.csv',
#  'sfmtaAVLRawData08122014.csv',
#  'sfmtaAVLRawData08122015.csv',
#  'sfmtaAVLRawData08122016.csv',
#  'sfmtaAVLRawData08132013.csv',
#  'sfmtaAVLRawData08132014.csv',
#  'sfmtaAVLRawData08132015.csv',
#  'sfmtaAVLRawData08132016.csv',
#  'sfmtaAVLRawData08142013.csv',
#  'sfmtaAVLRawData08142014.csv',
#  'sfmtaAVLRawData08142015.csv',
#  'sfmtaAVLRawData08142016.csv',
#  'sfmtaAVLRawData08152012.csv',
#  'sfmtaAVLRawData08152013.csv',
#  'sfmtaAVLRawData08152014.csv',
#  'sfmtaAVLRawData08152015.csv',
#  'sfmtaAVLRawData08152016.csv',
#  'sfmtaAVLRawData08162013.csv',
#  'sfmtaAVLRawData08162014.csv',
#  'sfmtaAVLRawData08162015.csv',
#  'sfmtaAVLRawData08162016.csv',
#  'sfmtaAVLRawData08172013.csv',
#  'sfmtaAVLRawData08172014.csv',
#  'sfmtaAVLRawData08172015.csv',
#  'sfmtaAVLRawData08172016.csv',
#  'sfmtaAVLRawData08182012.csv',
#  'sfmtaAVLRawData08182013.csv',
#  'sfmtaAVLRawData08182014.csv',
#  'sfmtaAVLRawData08182015.csv',
#  'sfmtaAVLRawData08182016.csv',
#  'sfmtaAVLRawData08192012.csv',
#  'sfmtaAVLRawData08192013.csv',
#  'sfmtaAVLRawData08192014.csv',
#  'sfmtaAVLRawData08192015.csv',
#  'sfmtaAVLRawData08192016.csv',
#  'sfmtaAVLRawData08202012.csv',
#  'sfmtaAVLRawData08202013.csv',
#  'sfmtaAVLRawData08202014.csv',
#  'sfmtaAVLRawData08202015.csv',
#  'sfmtaAVLRawData08202016.csv',
#  'sfmtaAVLRawData08212012.csv',
#  'sfmtaAVLRawData08212013.csv',
#  'sfmtaAVLRawData08212014.csv',
#  'sfmtaAVLRawData08212015.csv',
#  'sfmtaAVLRawData08212016.csv',
#  'sfmtaAVLRawData08222012.csv',
#  'sfmtaAVLRawData08222013.csv',
#  'sfmtaAVLRawData08222014.csv',
#  'sfmtaAVLRawData08222015.csv',
#  'sfmtaAVLRawData08222016.csv',
#  'sfmtaAVLRawData08232012.csv',
#  'sfmtaAVLRawData08232013.csv',
#  'sfmtaAVLRawData08232014.csv',
#  'sfmtaAVLRawData08232015.csv',
#  'sfmtaAVLRawData08232016.csv',
#  'sfmtaAVLRawData08242012.csv',
#  'sfmtaAVLRawData08242013.csv',
#  'sfmtaAVLRawData08242014.csv',
#  'sfmtaAVLRawData08242015.csv',
#  'sfmtaAVLRawData08242016.csv',
#  'sfmtaAVLRawData08252012.csv',
#  'sfmtaAVLRawData08252013.csv',
#  'sfmtaAVLRawData08252014.csv',
#  'sfmtaAVLRawData08252015.csv',
#  'sfmtaAVLRawData08252016.csv',
#  'sfmtaAVLRawData08262012.csv',
#  'sfmtaAVLRawData08262013.csv',
#  'sfmtaAVLRawData08262014.csv',
#  'sfmtaAVLRawData08262015.csv',
#  'sfmtaAVLRawData08262016.csv',
#  'sfmtaAVLRawData08272012.csv',
#  'sfmtaAVLRawData08272013.csv',
#  'sfmtaAVLRawData08272014.csv',
#  'sfmtaAVLRawData08272015.csv',
#  'sfmtaAVLRawData08272016.csv',
#  'sfmtaAVLRawData08282012.zip',
#  'sfmtaAVLRawData08282013.csv',
#  'sfmtaAVLRawData08282014.csv',
#  'sfmtaAVLRawData08282015.csv',
#  'sfmtaAVLRawData08282016.csv',
#  'sfmtaAVLRawData08292012.csv',
#  'sfmtaAVLRawData08292013.csv',
#  'sfmtaAVLRawData08292014.csv',
#  'sfmtaAVLRawData08292015.csv',
#  'sfmtaAVLRawData08292016.csv',
#  'sfmtaAVLRawData08302012.csv',
#  'sfmtaAVLRawData08302013.csv',
#  'sfmtaAVLRawData08302014.csv',
#  'sfmtaAVLRawData08302015.csv',
#  'sfmtaAVLRawData08302016.csv',
#  'sfmtaAVLRawData08312012.csv',
#  'sfmtaAVLRawData08312013.csv',
#  'sfmtaAVLRawData08312014.csv',
#  'sfmtaAVLRawData08312015.csv',
#  'sfmtaAVLRawData08312016.csv',
#  'sfmtaAVLRawData09012012.csv',
#  'sfmtaAVLRawData09012013.csv',
#  'sfmtaAVLRawData09012014.csv',
#  'sfmtaAVLRawData09012015.csv',
#  'sfmtaAVLRawData09012016.csv',
#  'sfmtaAVLRawData09022012.csv',
#  'sfmtaAVLRawData09022013.csv',
#  'sfmtaAVLRawData09022014.csv',
#  'sfmtaAVLRawData09022015.csv',
#  'sfmtaAVLRawData09022016.csv',
#  'sfmtaAVLRawData09032012.csv',
#  'sfmtaAVLRawData09032013.csv',
#  'sfmtaAVLRawData09032014.csv',
#  'sfmtaAVLRawData09032015.csv',
#  'sfmtaAVLRawData09032016.csv',
#  'sfmtaAVLRawData09042012.csv',
#  'sfmtaAVLRawData09042013.csv',
#  'sfmtaAVLRawData09042014.csv',
#  'sfmtaAVLRawData09042015.csv',
#  'sfmtaAVLRawData09042016.csv',
#  'sfmtaAVLRawData09052012.csv',
#  'sfmtaAVLRawData09052013.csv',
#  'sfmtaAVLRawData09052014.csv',
#  'sfmtaAVLRawData09052015.csv',
#  'sfmtaAVLRawData09052016.csv',
#  'sfmtaAVLRawData09062012.csv',
#  ...]

# %%
def clean_sort_file_list(file_list):
    
    """
    Input: A list of FTP file
    Output: A list of csv file dates, sorted with newest first
    """

    clean_dates = []

    for item in file_list:

        if item[0:11] != 'sfmtaAVLRaw':
            continue

        raw_date = item[15:-4]

        if raw_date[0] == '_':
            continue

        file_time_raw = datetime.strptime(raw_date, '%m%d%Y')

        clean_dates.append(file_time_raw)
        
        clean_dates.sort(reverse=True)
    
    return clean_dates

# %%
b = clean_sort_file_list(a)
b
# Out:
# [datetime.datetime(2016, 12, 5, 0, 0),
#  datetime.datetime(2016, 12, 4, 0, 0),
#  datetime.datetime(2016, 12, 3, 0, 0),
#  datetime.datetime(2016, 11, 23, 0, 0),
#  datetime.datetime(2016, 11, 22, 0, 0),
#  datetime.datetime(2016, 11, 21, 0, 0),
#  datetime.datetime(2016, 11, 20, 0, 0),
#  datetime.datetime(2016, 11, 19, 0, 0),
#  datetime.datetime(2016, 11, 18, 0, 0),
#  datetime.datetime(2016, 11, 17, 0, 0),
#  datetime.datetime(2016, 11, 16, 0, 0),
#  datetime.datetime(2016, 11, 15, 0, 0),
#  datetime.datetime(2016, 11, 14, 0, 0),
#  datetime.datetime(2016, 11, 13, 0, 0),
#  datetime.datetime(2016, 11, 12, 0, 0),
#  datetime.datetime(2016, 11, 11, 0, 0),
#  datetime.datetime(2016, 11, 10, 0, 0),
#  datetime.datetime(2016, 11, 9, 0, 0),
#  datetime.datetime(2016, 11, 8, 0, 0),
#  datetime.datetime(2016, 11, 7, 0, 0),
#  datetime.datetime(2016, 11, 6, 0, 0),
#  datetime.datetime(2016, 11, 5, 0, 0),
#  datetime.datetime(2016, 11, 4, 0, 0),
#  datetime.datetime(2016, 11, 3, 0, 0),
#  datetime.datetime(2016, 11, 2, 0, 0),
#  datetime.datetime(2016, 11, 1, 0, 0),
#  datetime.datetime(2016, 10, 31, 0, 0),
#  datetime.datetime(2016, 10, 30, 0, 0),
#  datetime.datetime(2016, 10, 29, 0, 0),
#  datetime.datetime(2016, 10, 28, 0, 0),
#  datetime.datetime(2016, 10, 27, 0, 0),
#  datetime.datetime(2016, 10, 26, 0, 0),
#  datetime.datetime(2016, 10, 25, 0, 0),
#  datetime.datetime(2016, 10, 24, 0, 0),
#  datetime.datetime(2016, 10, 23, 0, 0),
#  datetime.datetime(2016, 10, 22, 0, 0),
#  datetime.datetime(2016, 10, 21, 0, 0),
#  datetime.datetime(2016, 10, 20, 0, 0),
#  datetime.datetime(2016, 10, 19, 0, 0),
#  datetime.datetime(2016, 10, 18, 0, 0),
#  datetime.datetime(2016, 10, 17, 0, 0),
#  datetime.datetime(2016, 10, 16, 0, 0),
#  datetime.datetime(2016, 10, 15, 0, 0),
#  datetime.datetime(2016, 10, 14, 0, 0),
#  datetime.datetime(2016, 10, 13, 0, 0),
#  datetime.datetime(2016, 10, 12, 0, 0),
#  datetime.datetime(2016, 10, 11, 0, 0),
#  datetime.datetime(2016, 10, 10, 0, 0),
#  datetime.datetime(2016, 10, 9, 0, 0),
#  datetime.datetime(2016, 10, 8, 0, 0),
#  datetime.datetime(2016, 10, 7, 0, 0),
#  datetime.datetime(2016, 10, 6, 0, 0),
#  datetime.datetime(2016, 10, 5, 0, 0),
#  datetime.datetime(2016, 10, 4, 0, 0),
#  datetime.datetime(2016, 10, 3, 0, 0),
#  datetime.datetime(2016, 10, 2, 0, 0),
#  datetime.datetime(2016, 10, 1, 0, 0),
#  datetime.datetime(2016, 9, 30, 0, 0),
#  datetime.datetime(2016, 9, 29, 0, 0),
#  datetime.datetime(2016, 9, 28, 0, 0),
#  datetime.datetime(2016, 9, 27, 0, 0),
#  datetime.datetime(2016, 9, 26, 0, 0),
#  datetime.datetime(2016, 9, 25, 0, 0),
#  datetime.datetime(2016, 9, 24, 0, 0),
#  datetime.datetime(2016, 9, 23, 0, 0),
#  datetime.datetime(2016, 9, 22, 0, 0),
#  datetime.datetime(2016, 9, 21, 0, 0),
#  datetime.datetime(2016, 9, 20, 0, 0),
#  datetime.datetime(2016, 9, 19, 0, 0),
#  datetime.datetime(2016, 9, 18, 0, 0),
#  datetime.datetime(2016, 9, 17, 0, 0),
#  datetime.datetime(2016, 9, 16, 0, 0),
#  datetime.datetime(2016, 9, 15, 0, 0),
#  datetime.datetime(2016, 9, 14, 0, 0),
#  datetime.datetime(2016, 9, 13, 0, 0),
#  datetime.datetime(2016, 9, 12, 0, 0),
#  datetime.datetime(2016, 9, 11, 0, 0),
#  datetime.datetime(2016, 9, 10, 0, 0),
#  datetime.datetime(2016, 9, 9, 0, 0),
#  datetime.datetime(2016, 9, 8, 0, 0),
#  datetime.datetime(2016, 9, 7, 0, 0),
#  datetime.datetime(2016, 9, 6, 0, 0),
#  datetime.datetime(2016, 9, 5, 0, 0),
#  datetime.datetime(2016, 9, 4, 0, 0),
#  datetime.datetime(2016, 9, 3, 0, 0),
#  datetime.datetime(2016, 9, 2, 0, 0),
#  datetime.datetime(2016, 9, 1, 0, 0),
#  datetime.datetime(2016, 8, 31, 0, 0),
#  datetime.datetime(2016, 8, 30, 0, 0),
#  datetime.datetime(2016, 8, 29, 0, 0),
#  datetime.datetime(2016, 8, 28, 0, 0),
#  datetime.datetime(2016, 8, 27, 0, 0),
#  datetime.datetime(2016, 8, 26, 0, 0),
#  datetime.datetime(2016, 8, 25, 0, 0),
#  datetime.datetime(2016, 8, 24, 0, 0),
#  datetime.datetime(2016, 8, 23, 0, 0),
#  datetime.datetime(2016, 8, 22, 0, 0),
#  datetime.datetime(2016, 8, 21, 0, 0),
#  datetime.datetime(2016, 8, 20, 0, 0),
#  datetime.datetime(2016, 8, 19, 0, 0),
#  datetime.datetime(2016, 8, 18, 0, 0),
#  datetime.datetime(2016, 8, 17, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2016, 8, 15, 0, 0),
#  datetime.datetime(2016, 8, 14, 0, 0),
#  datetime.datetime(2016, 8, 13, 0, 0),
#  datetime.datetime(2016, 8, 12, 0, 0),
#  datetime.datetime(2016, 8, 11, 0, 0),
#  datetime.datetime(2016, 8, 10, 0, 0),
#  datetime.datetime(2016, 8, 9, 0, 0),
#  datetime.datetime(2016, 8, 8, 0, 0),
#  datetime.datetime(2016, 8, 7, 0, 0),
#  datetime.datetime(2016, 8, 6, 0, 0),
#  datetime.datetime(2016, 8, 5, 0, 0),
#  datetime.datetime(2016, 8, 4, 0, 0),
#  datetime.datetime(2016, 8, 3, 0, 0),
#  datetime.datetime(2016, 8, 2, 0, 0),
#  datetime.datetime(2016, 8, 1, 0, 0),
#  datetime.datetime(2016, 7, 31, 0, 0),
#  datetime.datetime(2016, 7, 30, 0, 0),
#  datetime.datetime(2016, 7, 29, 0, 0),
#  datetime.datetime(2016, 7, 28, 0, 0),
#  datetime.datetime(2016, 7, 27, 0, 0),
#  datetime.datetime(2016, 7, 26, 0, 0),
#  datetime.datetime(2016, 7, 25, 0, 0),
#  datetime.datetime(2016, 7, 24, 0, 0),
#  datetime.datetime(2016, 7, 23, 0, 0),
#  datetime.datetime(2016, 7, 22, 0, 0),
#  datetime.datetime(2016, 7, 21, 0, 0),
#  datetime.datetime(2016, 7, 20, 0, 0),
#  datetime.datetime(2016, 7, 19, 0, 0),
#  datetime.datetime(2016, 7, 18, 0, 0),
#  datetime.datetime(2016, 7, 17, 0, 0),
#  datetime.datetime(2016, 7, 16, 0, 0),
#  datetime.datetime(2016, 7, 15, 0, 0),
#  datetime.datetime(2016, 7, 14, 0, 0),
#  datetime.datetime(2016, 7, 13, 0, 0),
#  datetime.datetime(2016, 7, 12, 0, 0),
#  datetime.datetime(2016, 7, 11, 0, 0),
#  datetime.datetime(2016, 7, 10, 0, 0),
#  datetime.datetime(2016, 7, 9, 0, 0),
#  datetime.datetime(2016, 7, 8, 0, 0),
#  datetime.datetime(2016, 7, 7, 0, 0),
#  datetime.datetime(2016, 7, 6, 0, 0),
#  datetime.datetime(2016, 7, 5, 0, 0),
#  datetime.datetime(2016, 7, 4, 0, 0),
#  datetime.datetime(2016, 7, 3, 0, 0),
#  datetime.datetime(2016, 7, 2, 0, 0),
#  datetime.datetime(2016, 7, 1, 0, 0),
#  datetime.datetime(2016, 6, 30, 0, 0),
#  datetime.datetime(2016, 6, 29, 0, 0),
#  datetime.datetime(2016, 6, 28, 0, 0),
#  datetime.datetime(2016, 6, 27, 0, 0),
#  datetime.datetime(2016, 6, 26, 0, 0),
#  datetime.datetime(2016, 6, 25, 0, 0),
#  datetime.datetime(2016, 6, 24, 0, 0),
#  datetime.datetime(2016, 6, 23, 0, 0),
#  datetime.datetime(2016, 6, 22, 0, 0),
#  datetime.datetime(2016, 6, 21, 0, 0),
#  datetime.datetime(2016, 6, 20, 0, 0),
#  datetime.datetime(2016, 6, 19, 0, 0),
#  datetime.datetime(2016, 6, 18, 0, 0),
#  datetime.datetime(2016, 6, 17, 0, 0),
#  datetime.datetime(2016, 6, 16, 0, 0),
#  datetime.datetime(2016, 6, 15, 0, 0),
#  datetime.datetime(2016, 6, 14, 0, 0),
#  datetime.datetime(2016, 6, 13, 0, 0),
#  datetime.datetime(2016, 6, 12, 0, 0),
#  datetime.datetime(2016, 6, 11, 0, 0),
#  datetime.datetime(2016, 6, 10, 0, 0),
#  datetime.datetime(2016, 6, 9, 0, 0),
#  datetime.datetime(2016, 6, 8, 0, 0),
#  datetime.datetime(2016, 6, 7, 0, 0),
#  datetime.datetime(2016, 6, 6, 0, 0),
#  datetime.datetime(2016, 6, 5, 0, 0),
#  datetime.datetime(2016, 6, 4, 0, 0),
#  datetime.datetime(2016, 6, 3, 0, 0),
#  datetime.datetime(2016, 6, 2, 0, 0),
#  datetime.datetime(2016, 6, 1, 0, 0),
#  datetime.datetime(2016, 5, 31, 0, 0),
#  datetime.datetime(2016, 5, 30, 0, 0),
#  datetime.datetime(2016, 5, 29, 0, 0),
#  datetime.datetime(2016, 5, 28, 0, 0),
#  datetime.datetime(2016, 5, 27, 0, 0),
#  datetime.datetime(2016, 5, 26, 0, 0),
#  datetime.datetime(2016, 5, 25, 0, 0),
#  datetime.datetime(2016, 5, 24, 0, 0),
#  datetime.datetime(2016, 5, 23, 0, 0),
#  datetime.datetime(2016, 5, 22, 0, 0),
#  datetime.datetime(2016, 5, 21, 0, 0),
#  datetime.datetime(2016, 5, 20, 0, 0),
#  datetime.datetime(2016, 5, 19, 0, 0),
#  datetime.datetime(2016, 5, 18, 0, 0),
#  datetime.datetime(2016, 5, 17, 0, 0),
#  datetime.datetime(2016, 5, 16, 0, 0),
#  datetime.datetime(2016, 5, 15, 0, 0),
#  datetime.datetime(2016, 5, 14, 0, 0),
#  datetime.datetime(2016, 5, 13, 0, 0),
#  datetime.datetime(2016, 5, 12, 0, 0),
#  datetime.datetime(2016, 5, 11, 0, 0),
#  datetime.datetime(2016, 5, 10, 0, 0),
#  datetime.datetime(2016, 5, 9, 0, 0),
#  datetime.datetime(2016, 5, 8, 0, 0),
#  datetime.datetime(2016, 5, 7, 0, 0),
#  datetime.datetime(2016, 5, 6, 0, 0),
#  datetime.datetime(2016, 5, 5, 0, 0),
#  datetime.datetime(2016, 5, 4, 0, 0),
#  datetime.datetime(2016, 5, 3, 0, 0),
#  datetime.datetime(2016, 5, 2, 0, 0),
#  datetime.datetime(2016, 5, 1, 0, 0),
#  datetime.datetime(2016, 4, 30, 0, 0),
#  datetime.datetime(2016, 4, 29, 0, 0),
#  datetime.datetime(2016, 4, 28, 0, 0),
#  datetime.datetime(2016, 4, 27, 0, 0),
#  datetime.datetime(2016, 4, 26, 0, 0),
#  datetime.datetime(2016, 4, 25, 0, 0),
#  datetime.datetime(2016, 4, 24, 0, 0),
#  datetime.datetime(2016, 4, 23, 0, 0),
#  datetime.datetime(2016, 4, 22, 0, 0),
#  datetime.datetime(2016, 4, 21, 0, 0),
#  datetime.datetime(2016, 4, 20, 0, 0),
#  datetime.datetime(2016, 4, 19, 0, 0),
#  datetime.datetime(2016, 4, 17, 0, 0),
#  datetime.datetime(2016, 4, 16, 0, 0),
#  datetime.datetime(2016, 4, 15, 0, 0),
#  datetime.datetime(2016, 4, 14, 0, 0),
#  datetime.datetime(2016, 4, 13, 0, 0),
#  datetime.datetime(2016, 4, 12, 0, 0),
#  datetime.datetime(2016, 4, 11, 0, 0),
#  datetime.datetime(2016, 4, 10, 0, 0),
#  datetime.datetime(2016, 4, 9, 0, 0),
#  datetime.datetime(2016, 4, 8, 0, 0),
#  datetime.datetime(2016, 4, 7, 0, 0),
#  datetime.datetime(2016, 4, 6, 0, 0),
#  datetime.datetime(2016, 4, 5, 0, 0),
#  datetime.datetime(2016, 4, 4, 0, 0),
#  datetime.datetime(2016, 4, 3, 0, 0),
#  datetime.datetime(2016, 4, 2, 0, 0),
#  datetime.datetime(2016, 4, 1, 0, 0),
#  datetime.datetime(2016, 3, 31, 0, 0),
#  datetime.datetime(2016, 3, 30, 0, 0),
#  datetime.datetime(2016, 3, 29, 0, 0),
#  datetime.datetime(2016, 3, 28, 0, 0),
#  datetime.datetime(2016, 3, 27, 0, 0),
#  datetime.datetime(2016, 3, 26, 0, 0),
#  datetime.datetime(2016, 3, 25, 0, 0),
#  datetime.datetime(2016, 3, 24, 0, 0),
#  datetime.datetime(2016, 3, 23, 0, 0),
#  datetime.datetime(2016, 3, 22, 0, 0),
#  datetime.datetime(2016, 3, 21, 0, 0),
#  datetime.datetime(2016, 3, 20, 0, 0),
#  datetime.datetime(2016, 3, 19, 0, 0),
#  datetime.datetime(2016, 3, 18, 0, 0),
#  datetime.datetime(2016, 3, 17, 0, 0),
#  datetime.datetime(2016, 3, 16, 0, 0),
#  datetime.datetime(2016, 3, 15, 0, 0),
#  datetime.datetime(2016, 3, 14, 0, 0),
#  datetime.datetime(2016, 3, 13, 0, 0),
#  datetime.datetime(2016, 3, 12, 0, 0),
#  datetime.datetime(2016, 3, 11, 0, 0),
#  datetime.datetime(2016, 3, 10, 0, 0),
#  datetime.datetime(2016, 3, 9, 0, 0),
#  datetime.datetime(2016, 3, 8, 0, 0),
#  datetime.datetime(2016, 3, 7, 0, 0),
#  datetime.datetime(2016, 3, 6, 0, 0),
#  datetime.datetime(2016, 3, 5, 0, 0),
#  datetime.datetime(2016, 3, 4, 0, 0),
#  datetime.datetime(2016, 3, 3, 0, 0),
#  datetime.datetime(2016, 3, 2, 0, 0),
#  datetime.datetime(2016, 3, 1, 0, 0),
#  datetime.datetime(2016, 2, 29, 0, 0),
#  datetime.datetime(2016, 2, 28, 0, 0),
#  datetime.datetime(2016, 2, 27, 0, 0),
#  datetime.datetime(2016, 2, 26, 0, 0),
#  datetime.datetime(2016, 2, 25, 0, 0),
#  datetime.datetime(2016, 2, 24, 0, 0),
#  datetime.datetime(2016, 2, 23, 0, 0),
#  datetime.datetime(2016, 2, 22, 0, 0),
#  datetime.datetime(2016, 2, 21, 0, 0),
#  datetime.datetime(2016, 2, 20, 0, 0),
#  datetime.datetime(2016, 2, 19, 0, 0),
#  datetime.datetime(2016, 2, 18, 0, 0),
#  datetime.datetime(2016, 2, 17, 0, 0),
#  datetime.datetime(2016, 2, 16, 0, 0),
#  datetime.datetime(2016, 2, 15, 0, 0),
#  datetime.datetime(2016, 2, 14, 0, 0),
#  datetime.datetime(2016, 2, 13, 0, 0),
#  datetime.datetime(2016, 2, 12, 0, 0),
#  datetime.datetime(2016, 2, 11, 0, 0),
#  datetime.datetime(2016, 2, 10, 0, 0),
#  datetime.datetime(2016, 2, 9, 0, 0),
#  datetime.datetime(2016, 2, 8, 0, 0),
#  datetime.datetime(2016, 2, 7, 0, 0),
#  datetime.datetime(2016, 2, 6, 0, 0),
#  datetime.datetime(2016, 2, 5, 0, 0),
#  datetime.datetime(2016, 2, 4, 0, 0),
#  datetime.datetime(2016, 2, 3, 0, 0),
#  datetime.datetime(2016, 2, 2, 0, 0),
#  datetime.datetime(2016, 2, 1, 0, 0),
#  datetime.datetime(2016, 1, 31, 0, 0),
#  datetime.datetime(2016, 1, 30, 0, 0),
#  datetime.datetime(2016, 1, 29, 0, 0),
#  datetime.datetime(2016, 1, 28, 0, 0),
#  datetime.datetime(2016, 1, 27, 0, 0),
#  datetime.datetime(2016, 1, 26, 0, 0),
#  datetime.datetime(2016, 1, 25, 0, 0),
#  datetime.datetime(2016, 1, 24, 0, 0),
#  datetime.datetime(2016, 1, 23, 0, 0),
#  datetime.datetime(2016, 1, 22, 0, 0),
#  datetime.datetime(2016, 1, 21, 0, 0),
#  datetime.datetime(2016, 1, 20, 0, 0),
#  datetime.datetime(2016, 1, 19, 0, 0),
#  datetime.datetime(2016, 1, 18, 0, 0),
#  datetime.datetime(2016, 1, 17, 0, 0),
#  datetime.datetime(2016, 1, 16, 0, 0),
#  datetime.datetime(2016, 1, 15, 0, 0),
#  datetime.datetime(2016, 1, 14, 0, 0),
#  datetime.datetime(2016, 1, 13, 0, 0),
#  datetime.datetime(2016, 1, 12, 0, 0),
#  datetime.datetime(2016, 1, 11, 0, 0),
#  datetime.datetime(2016, 1, 10, 0, 0),
#  datetime.datetime(2016, 1, 9, 0, 0),
#  datetime.datetime(2016, 1, 8, 0, 0),
#  datetime.datetime(2016, 1, 7, 0, 0),
#  datetime.datetime(2016, 1, 6, 0, 0),
#  datetime.datetime(2016, 1, 5, 0, 0),
#  datetime.datetime(2016, 1, 4, 0, 0),
#  datetime.datetime(2016, 1, 3, 0, 0),
#  datetime.datetime(2015, 12, 28, 0, 0),
#  datetime.datetime(2015, 12, 27, 0, 0),
#  datetime.datetime(2015, 12, 26, 0, 0),
#  datetime.datetime(2015, 12, 25, 0, 0),
#  datetime.datetime(2015, 12, 24, 0, 0),
#  datetime.datetime(2015, 12, 23, 0, 0),
#  datetime.datetime(2015, 12, 22, 0, 0),
#  datetime.datetime(2015, 12, 21, 0, 0),
#  datetime.datetime(2015, 12, 20, 0, 0),
#  datetime.datetime(2015, 12, 19, 0, 0),
#  datetime.datetime(2015, 12, 18, 0, 0),
#  datetime.datetime(2015, 12, 17, 0, 0),
#  datetime.datetime(2015, 12, 16, 0, 0),
#  datetime.datetime(2015, 12, 15, 0, 0),
#  datetime.datetime(2015, 12, 14, 0, 0),
#  datetime.datetime(2015, 12, 13, 0, 0),
#  datetime.datetime(2015, 12, 12, 0, 0),
#  datetime.datetime(2015, 12, 11, 0, 0),
#  datetime.datetime(2015, 12, 10, 0, 0),
#  datetime.datetime(2015, 12, 9, 0, 0),
#  datetime.datetime(2015, 12, 8, 0, 0),
#  datetime.datetime(2015, 12, 7, 0, 0),
#  datetime.datetime(2015, 12, 6, 0, 0),
#  datetime.datetime(2015, 12, 5, 0, 0),
#  datetime.datetime(2015, 12, 4, 0, 0),
#  datetime.datetime(2015, 12, 3, 0, 0),
#  datetime.datetime(2015, 12, 2, 0, 0),
#  datetime.datetime(2015, 12, 1, 0, 0),
#  datetime.datetime(2015, 11, 30, 0, 0),
#  datetime.datetime(2015, 11, 29, 0, 0),
#  datetime.datetime(2015, 11, 28, 0, 0),
#  datetime.datetime(2015, 11, 27, 0, 0),
#  datetime.datetime(2015, 11, 26, 0, 0),
#  datetime.datetime(2015, 11, 25, 0, 0),
#  datetime.datetime(2015, 11, 24, 0, 0),
#  datetime.datetime(2015, 11, 23, 0, 0),
#  datetime.datetime(2015, 11, 22, 0, 0),
#  datetime.datetime(2015, 11, 21, 0, 0),
#  datetime.datetime(2015, 11, 20, 0, 0),
#  datetime.datetime(2015, 11, 19, 0, 0),
#  datetime.datetime(2015, 11, 18, 0, 0),
#  datetime.datetime(2015, 11, 17, 0, 0),
#  datetime.datetime(2015, 11, 16, 0, 0),
#  datetime.datetime(2015, 11, 15, 0, 0),
#  datetime.datetime(2015, 11, 14, 0, 0),
#  datetime.datetime(2015, 11, 13, 0, 0),
#  datetime.datetime(2015, 11, 12, 0, 0),
#  datetime.datetime(2015, 11, 11, 0, 0),
#  datetime.datetime(2015, 11, 10, 0, 0),
#  datetime.datetime(2015, 11, 9, 0, 0),
#  datetime.datetime(2015, 11, 8, 0, 0),
#  datetime.datetime(2015, 11, 7, 0, 0),
#  datetime.datetime(2015, 11, 6, 0, 0),
#  datetime.datetime(2015, 11, 5, 0, 0),
#  datetime.datetime(2015, 11, 4, 0, 0),
#  datetime.datetime(2015, 11, 3, 0, 0),
#  datetime.datetime(2015, 11, 2, 0, 0),
#  datetime.datetime(2015, 11, 1, 0, 0),
#  datetime.datetime(2015, 10, 31, 0, 0),
#  datetime.datetime(2015, 10, 30, 0, 0),
#  datetime.datetime(2015, 10, 29, 0, 0),
#  datetime.datetime(2015, 10, 28, 0, 0),
#  datetime.datetime(2015, 10, 27, 0, 0),
#  datetime.datetime(2015, 10, 26, 0, 0),
#  datetime.datetime(2015, 10, 25, 0, 0),
#  datetime.datetime(2015, 10, 24, 0, 0),
#  datetime.datetime(2015, 10, 23, 0, 0),
#  datetime.datetime(2015, 10, 22, 0, 0),
#  datetime.datetime(2015, 10, 21, 0, 0),
#  datetime.datetime(2015, 10, 20, 0, 0),
#  datetime.datetime(2015, 10, 19, 0, 0),
#  datetime.datetime(2015, 10, 18, 0, 0),
#  datetime.datetime(2015, 10, 17, 0, 0),
#  datetime.datetime(2015, 10, 16, 0, 0),
#  datetime.datetime(2015, 10, 15, 0, 0),
#  datetime.datetime(2015, 10, 14, 0, 0),
#  datetime.datetime(2015, 10, 13, 0, 0),
#  datetime.datetime(2015, 10, 12, 0, 0),
#  datetime.datetime(2015, 10, 11, 0, 0),
#  datetime.datetime(2015, 10, 10, 0, 0),
#  datetime.datetime(2015, 10, 9, 0, 0),
#  datetime.datetime(2015, 10, 8, 0, 0),
#  datetime.datetime(2015, 10, 7, 0, 0),
#  datetime.datetime(2015, 10, 6, 0, 0),
#  datetime.datetime(2015, 10, 5, 0, 0),
#  datetime.datetime(2015, 10, 4, 0, 0),
#  datetime.datetime(2015, 10, 3, 0, 0),
#  datetime.datetime(2015, 10, 2, 0, 0),
#  datetime.datetime(2015, 10, 1, 0, 0),
#  datetime.datetime(2015, 9, 30, 0, 0),
#  datetime.datetime(2015, 9, 29, 0, 0),
#  datetime.datetime(2015, 9, 28, 0, 0),
#  datetime.datetime(2015, 9, 27, 0, 0),
#  datetime.datetime(2015, 9, 26, 0, 0),
#  datetime.datetime(2015, 9, 25, 0, 0),
#  datetime.datetime(2015, 9, 24, 0, 0),
#  datetime.datetime(2015, 9, 23, 0, 0),
#  datetime.datetime(2015, 9, 22, 0, 0),
#  datetime.datetime(2015, 9, 21, 0, 0),
#  datetime.datetime(2015, 9, 20, 0, 0),
#  datetime.datetime(2015, 9, 19, 0, 0),
#  datetime.datetime(2015, 9, 18, 0, 0),
#  datetime.datetime(2015, 9, 17, 0, 0),
#  datetime.datetime(2015, 9, 16, 0, 0),
#  datetime.datetime(2015, 9, 15, 0, 0),
#  datetime.datetime(2015, 9, 14, 0, 0),
#  datetime.datetime(2015, 9, 13, 0, 0),
#  datetime.datetime(2015, 9, 12, 0, 0),
#  datetime.datetime(2015, 9, 11, 0, 0),
#  datetime.datetime(2015, 9, 10, 0, 0),
#  datetime.datetime(2015, 9, 9, 0, 0),
#  datetime.datetime(2015, 9, 8, 0, 0),
#  datetime.datetime(2015, 9, 7, 0, 0),
#  datetime.datetime(2015, 9, 6, 0, 0),
#  datetime.datetime(2015, 9, 5, 0, 0),
#  datetime.datetime(2015, 9, 4, 0, 0),
#  datetime.datetime(2015, 9, 3, 0, 0),
#  datetime.datetime(2015, 9, 2, 0, 0),
#  datetime.datetime(2015, 9, 1, 0, 0),
#  datetime.datetime(2015, 8, 31, 0, 0),
#  datetime.datetime(2015, 8, 30, 0, 0),
#  datetime.datetime(2015, 8, 29, 0, 0),
#  datetime.datetime(2015, 8, 28, 0, 0),
#  datetime.datetime(2015, 8, 27, 0, 0),
#  datetime.datetime(2015, 8, 26, 0, 0),
#  datetime.datetime(2015, 8, 25, 0, 0),
#  datetime.datetime(2015, 8, 24, 0, 0),
#  datetime.datetime(2015, 8, 23, 0, 0),
#  datetime.datetime(2015, 8, 22, 0, 0),
#  datetime.datetime(2015, 8, 21, 0, 0),
#  datetime.datetime(2015, 8, 20, 0, 0),
#  datetime.datetime(2015, 8, 19, 0, 0),
#  datetime.datetime(2015, 8, 18, 0, 0),
#  datetime.datetime(2015, 8, 17, 0, 0),
#  datetime.datetime(2015, 8, 16, 0, 0),
#  datetime.datetime(2015, 8, 15, 0, 0),
#  datetime.datetime(2015, 8, 14, 0, 0),
#  datetime.datetime(2015, 8, 13, 0, 0),
#  datetime.datetime(2015, 8, 12, 0, 0),
#  datetime.datetime(2015, 8, 11, 0, 0),
#  datetime.datetime(2015, 8, 10, 0, 0),
#  datetime.datetime(2015, 8, 9, 0, 0),
#  datetime.datetime(2015, 8, 8, 0, 0),
#  datetime.datetime(2015, 8, 7, 0, 0),
#  datetime.datetime(2015, 8, 6, 0, 0),
#  datetime.datetime(2015, 8, 5, 0, 0),
#  datetime.datetime(2015, 8, 4, 0, 0),
#  datetime.datetime(2015, 8, 3, 0, 0),
#  datetime.datetime(2015, 8, 2, 0, 0),
#  datetime.datetime(2015, 8, 1, 0, 0),
#  datetime.datetime(2015, 7, 31, 0, 0),
#  datetime.datetime(2015, 7, 30, 0, 0),
#  datetime.datetime(2015, 7, 29, 0, 0),
#  datetime.datetime(2015, 7, 28, 0, 0),
#  datetime.datetime(2015, 7, 27, 0, 0),
#  datetime.datetime(2015, 7, 26, 0, 0),
#  datetime.datetime(2015, 7, 25, 0, 0),
#  datetime.datetime(2015, 7, 24, 0, 0),
#  datetime.datetime(2015, 7, 23, 0, 0),
#  datetime.datetime(2015, 7, 22, 0, 0),
#  datetime.datetime(2015, 7, 21, 0, 0),
#  datetime.datetime(2015, 7, 20, 0, 0),
#  datetime.datetime(2015, 7, 19, 0, 0),
#  datetime.datetime(2015, 7, 18, 0, 0),
#  datetime.datetime(2015, 7, 17, 0, 0),
#  datetime.datetime(2015, 7, 16, 0, 0),
#  datetime.datetime(2015, 7, 15, 0, 0),
#  datetime.datetime(2015, 7, 14, 0, 0),
#  datetime.datetime(2015, 7, 13, 0, 0),
#  datetime.datetime(2015, 7, 12, 0, 0),
#  datetime.datetime(2015, 7, 11, 0, 0),
#  datetime.datetime(2015, 7, 10, 0, 0),
#  datetime.datetime(2015, 7, 9, 0, 0),
#  datetime.datetime(2015, 7, 8, 0, 0),
#  datetime.datetime(2015, 7, 7, 0, 0),
#  datetime.datetime(2015, 7, 6, 0, 0),
#  datetime.datetime(2015, 7, 5, 0, 0),
#  datetime.datetime(2015, 7, 4, 0, 0),
#  datetime.datetime(2015, 7, 3, 0, 0),
#  datetime.datetime(2015, 7, 2, 0, 0),
#  datetime.datetime(2015, 7, 1, 0, 0),
#  datetime.datetime(2015, 6, 30, 0, 0),
#  datetime.datetime(2015, 6, 29, 0, 0),
#  datetime.datetime(2015, 6, 28, 0, 0),
#  datetime.datetime(2015, 6, 27, 0, 0),
#  datetime.datetime(2015, 6, 26, 0, 0),
#  datetime.datetime(2015, 6, 25, 0, 0),
#  datetime.datetime(2015, 6, 24, 0, 0),
#  datetime.datetime(2015, 6, 23, 0, 0),
#  datetime.datetime(2015, 6, 22, 0, 0),
#  datetime.datetime(2015, 6, 21, 0, 0),
#  datetime.datetime(2015, 6, 20, 0, 0),
#  datetime.datetime(2015, 6, 19, 0, 0),
#  datetime.datetime(2015, 6, 18, 0, 0),
#  datetime.datetime(2015, 6, 17, 0, 0),
#  datetime.datetime(2015, 6, 16, 0, 0),
#  datetime.datetime(2015, 6, 15, 0, 0),
#  datetime.datetime(2015, 6, 14, 0, 0),
#  datetime.datetime(2015, 6, 13, 0, 0),
#  datetime.datetime(2015, 6, 12, 0, 0),
#  datetime.datetime(2015, 6, 11, 0, 0),
#  datetime.datetime(2015, 6, 10, 0, 0),
#  datetime.datetime(2015, 6, 9, 0, 0),
#  datetime.datetime(2015, 6, 8, 0, 0),
#  datetime.datetime(2015, 6, 7, 0, 0),
#  datetime.datetime(2015, 6, 6, 0, 0),
#  datetime.datetime(2015, 6, 5, 0, 0),
#  datetime.datetime(2015, 6, 4, 0, 0),
#  datetime.datetime(2015, 6, 3, 0, 0),
#  datetime.datetime(2015, 6, 2, 0, 0),
#  datetime.datetime(2015, 6, 1, 0, 0),
#  datetime.datetime(2015, 5, 31, 0, 0),
#  datetime.datetime(2015, 5, 30, 0, 0),
#  datetime.datetime(2015, 5, 29, 0, 0),
#  datetime.datetime(2015, 5, 28, 0, 0),
#  datetime.datetime(2015, 5, 21, 0, 0),
#  datetime.datetime(2015, 5, 20, 0, 0),
#  datetime.datetime(2015, 5, 19, 0, 0),
#  datetime.datetime(2015, 5, 18, 0, 0),
#  datetime.datetime(2015, 5, 17, 0, 0),
#  datetime.datetime(2015, 5, 16, 0, 0),
#  datetime.datetime(2015, 5, 15, 0, 0),
#  datetime.datetime(2015, 5, 14, 0, 0),
#  datetime.datetime(2015, 5, 13, 0, 0),
#  datetime.datetime(2015, 5, 12, 0, 0),
#  datetime.datetime(2015, 5, 11, 0, 0),
#  datetime.datetime(2015, 5, 10, 0, 0),
#  datetime.datetime(2015, 5, 9, 0, 0),
#  datetime.datetime(2015, 5, 8, 0, 0),
#  datetime.datetime(2015, 5, 7, 0, 0),
#  datetime.datetime(2015, 5, 6, 0, 0),
#  datetime.datetime(2015, 5, 5, 0, 0),
#  datetime.datetime(2015, 5, 4, 0, 0),
#  datetime.datetime(2015, 5, 3, 0, 0),
#  datetime.datetime(2015, 5, 2, 0, 0),
#  datetime.datetime(2015, 5, 1, 0, 0),
#  datetime.datetime(2015, 4, 30, 0, 0),
#  datetime.datetime(2015, 4, 29, 0, 0),
#  datetime.datetime(2015, 4, 28, 0, 0),
#  datetime.datetime(2015, 4, 27, 0, 0),
#  datetime.datetime(2015, 4, 26, 0, 0),
#  datetime.datetime(2015, 4, 25, 0, 0),
#  datetime.datetime(2015, 4, 24, 0, 0),
#  datetime.datetime(2015, 4, 23, 0, 0),
#  datetime.datetime(2015, 4, 22, 0, 0),
#  datetime.datetime(2015, 4, 21, 0, 0),
#  datetime.datetime(2015, 4, 20, 0, 0),
#  datetime.datetime(2015, 4, 19, 0, 0),
#  datetime.datetime(2015, 4, 18, 0, 0),
#  datetime.datetime(2015, 4, 17, 0, 0),
#  datetime.datetime(2015, 4, 16, 0, 0),
#  datetime.datetime(2015, 4, 15, 0, 0),
#  datetime.datetime(2015, 4, 14, 0, 0),
#  datetime.datetime(2015, 4, 13, 0, 0),
#  datetime.datetime(2015, 4, 12, 0, 0),
#  datetime.datetime(2015, 4, 11, 0, 0),
#  datetime.datetime(2015, 4, 10, 0, 0),
#  datetime.datetime(2015, 4, 9, 0, 0),
#  datetime.datetime(2015, 4, 8, 0, 0),
#  datetime.datetime(2015, 4, 7, 0, 0),
#  datetime.datetime(2015, 4, 6, 0, 0),
#  datetime.datetime(2015, 4, 5, 0, 0),
#  datetime.datetime(2015, 4, 4, 0, 0),
#  datetime.datetime(2015, 4, 2, 0, 0),
#  datetime.datetime(2015, 4, 1, 0, 0),
#  datetime.datetime(2015, 3, 31, 0, 0),
#  datetime.datetime(2015, 3, 30, 0, 0),
#  datetime.datetime(2015, 3, 29, 0, 0),
#  datetime.datetime(2015, 3, 28, 0, 0),
#  datetime.datetime(2015, 3, 27, 0, 0),
#  datetime.datetime(2015, 3, 26, 0, 0),
#  datetime.datetime(2015, 3, 25, 0, 0),
#  datetime.datetime(2015, 3, 24, 0, 0),
#  datetime.datetime(2015, 3, 23, 0, 0),
#  datetime.datetime(2015, 3, 21, 0, 0),
#  datetime.datetime(2015, 3, 20, 0, 0),
#  datetime.datetime(2015, 3, 19, 0, 0),
#  datetime.datetime(2015, 3, 18, 0, 0),
#  datetime.datetime(2015, 3, 17, 0, 0),
#  datetime.datetime(2015, 3, 16, 0, 0),
#  datetime.datetime(2015, 3, 15, 0, 0),
#  datetime.datetime(2015, 3, 14, 0, 0),
#  datetime.datetime(2015, 3, 13, 0, 0),
#  datetime.datetime(2015, 3, 12, 0, 0),
#  datetime.datetime(2015, 3, 11, 0, 0),
#  datetime.datetime(2015, 3, 10, 0, 0),
#  datetime.datetime(2015, 3, 9, 0, 0),
#  datetime.datetime(2015, 3, 8, 0, 0),
#  datetime.datetime(2015, 3, 7, 0, 0),
#  datetime.datetime(2015, 3, 6, 0, 0),
#  datetime.datetime(2015, 3, 5, 0, 0),
#  datetime.datetime(2015, 3, 4, 0, 0),
#  datetime.datetime(2015, 3, 3, 0, 0),
#  datetime.datetime(2015, 3, 2, 0, 0),
#  datetime.datetime(2015, 3, 1, 0, 0),
#  datetime.datetime(2015, 2, 28, 0, 0),
#  datetime.datetime(2015, 2, 27, 0, 0),
#  datetime.datetime(2015, 2, 26, 0, 0),
#  datetime.datetime(2015, 2, 25, 0, 0),
#  datetime.datetime(2015, 2, 23, 0, 0),
#  datetime.datetime(2015, 2, 22, 0, 0),
#  datetime.datetime(2015, 2, 21, 0, 0),
#  datetime.datetime(2015, 2, 20, 0, 0),
#  datetime.datetime(2015, 2, 19, 0, 0),
#  datetime.datetime(2015, 2, 18, 0, 0),
#  datetime.datetime(2015, 2, 17, 0, 0),
#  datetime.datetime(2015, 2, 16, 0, 0),
#  datetime.datetime(2015, 2, 15, 0, 0),
#  datetime.datetime(2015, 2, 14, 0, 0),
#  datetime.datetime(2015, 2, 13, 0, 0),
#  datetime.datetime(2015, 2, 12, 0, 0),
#  datetime.datetime(2015, 2, 11, 0, 0),
#  datetime.datetime(2015, 2, 10, 0, 0),
#  datetime.datetime(2015, 2, 9, 0, 0),
#  datetime.datetime(2015, 2, 8, 0, 0),
#  datetime.datetime(2015, 2, 7, 0, 0),
#  datetime.datetime(2015, 2, 6, 0, 0),
#  datetime.datetime(2015, 2, 5, 0, 0),
#  datetime.datetime(2015, 2, 4, 0, 0),
#  datetime.datetime(2015, 2, 2, 0, 0),
#  datetime.datetime(2015, 2, 1, 0, 0),
#  datetime.datetime(2015, 1, 31, 0, 0),
#  datetime.datetime(2015, 1, 30, 0, 0),
#  datetime.datetime(2015, 1, 29, 0, 0),
#  datetime.datetime(2015, 1, 28, 0, 0),
#  datetime.datetime(2015, 1, 27, 0, 0),
#  datetime.datetime(2015, 1, 26, 0, 0),
#  datetime.datetime(2015, 1, 25, 0, 0),
#  datetime.datetime(2015, 1, 24, 0, 0),
#  datetime.datetime(2015, 1, 23, 0, 0),
#  datetime.datetime(2015, 1, 22, 0, 0),
#  datetime.datetime(2015, 1, 21, 0, 0),
#  datetime.datetime(2015, 1, 20, 0, 0),
#  datetime.datetime(2015, 1, 19, 0, 0),
#  datetime.datetime(2015, 1, 18, 0, 0),
#  datetime.datetime(2015, 1, 17, 0, 0),
#  datetime.datetime(2015, 1, 16, 0, 0),
#  datetime.datetime(2015, 1, 15, 0, 0),
#  datetime.datetime(2015, 1, 14, 0, 0),
#  datetime.datetime(2015, 1, 13, 0, 0),
#  datetime.datetime(2015, 1, 12, 0, 0),
#  datetime.datetime(2015, 1, 11, 0, 0),
#  datetime.datetime(2015, 1, 10, 0, 0),
#  datetime.datetime(2015, 1, 9, 0, 0),
#  datetime.datetime(2015, 1, 8, 0, 0),
#  datetime.datetime(2015, 1, 7, 0, 0),
#  datetime.datetime(2015, 1, 6, 0, 0),
#  datetime.datetime(2015, 1, 5, 0, 0),
#  datetime.datetime(2015, 1, 4, 0, 0),
#  datetime.datetime(2015, 1, 3, 0, 0),
#  datetime.datetime(2015, 1, 2, 0, 0),
#  datetime.datetime(2015, 1, 1, 0, 0),
#  datetime.datetime(2014, 12, 31, 0, 0),
#  datetime.datetime(2014, 12, 30, 0, 0),
#  datetime.datetime(2014, 12, 29, 0, 0),
#  datetime.datetime(2014, 12, 26, 0, 0),
#  datetime.datetime(2014, 12, 25, 0, 0),
#  datetime.datetime(2014, 12, 24, 0, 0),
#  datetime.datetime(2014, 12, 23, 0, 0),
#  datetime.datetime(2014, 12, 22, 0, 0),
#  datetime.datetime(2014, 12, 21, 0, 0),
#  datetime.datetime(2014, 12, 20, 0, 0),
#  datetime.datetime(2014, 12, 19, 0, 0),
#  datetime.datetime(2014, 12, 18, 0, 0),
#  datetime.datetime(2014, 12, 17, 0, 0),
#  datetime.datetime(2014, 12, 16, 0, 0),
#  datetime.datetime(2014, 12, 15, 0, 0),
#  datetime.datetime(2014, 12, 14, 0, 0),
#  datetime.datetime(2014, 12, 13, 0, 0),
#  datetime.datetime(2014, 12, 12, 0, 0),
#  datetime.datetime(2014, 12, 11, 0, 0),
#  datetime.datetime(2014, 12, 10, 0, 0),
#  datetime.datetime(2014, 12, 9, 0, 0),
#  datetime.datetime(2014, 12, 8, 0, 0),
#  datetime.datetime(2014, 12, 7, 0, 0),
#  datetime.datetime(2014, 12, 6, 0, 0),
#  datetime.datetime(2014, 12, 5, 0, 0),
#  datetime.datetime(2014, 12, 4, 0, 0),
#  datetime.datetime(2014, 12, 3, 0, 0),
#  datetime.datetime(2014, 12, 2, 0, 0),
#  datetime.datetime(2014, 12, 1, 0, 0),
#  datetime.datetime(2014, 11, 30, 0, 0),
#  datetime.datetime(2014, 11, 29, 0, 0),
#  datetime.datetime(2014, 11, 28, 0, 0),
#  datetime.datetime(2014, 11, 27, 0, 0),
#  datetime.datetime(2014, 11, 26, 0, 0),
#  datetime.datetime(2014, 11, 25, 0, 0),
#  datetime.datetime(2014, 11, 24, 0, 0),
#  datetime.datetime(2014, 11, 23, 0, 0),
#  datetime.datetime(2014, 11, 22, 0, 0),
#  datetime.datetime(2014, 11, 21, 0, 0),
#  datetime.datetime(2014, 11, 20, 0, 0),
#  datetime.datetime(2014, 11, 19, 0, 0),
#  datetime.datetime(2014, 11, 18, 0, 0),
#  datetime.datetime(2014, 11, 17, 0, 0),
#  datetime.datetime(2014, 11, 16, 0, 0),
#  datetime.datetime(2014, 11, 15, 0, 0),
#  datetime.datetime(2014, 11, 14, 0, 0),
#  datetime.datetime(2014, 11, 13, 0, 0),
#  datetime.datetime(2014, 11, 12, 0, 0),
#  datetime.datetime(2014, 11, 11, 0, 0),
#  datetime.datetime(2014, 11, 10, 0, 0),
#  datetime.datetime(2014, 11, 9, 0, 0),
#  datetime.datetime(2014, 11, 8, 0, 0),
#  datetime.datetime(2014, 11, 7, 0, 0),
#  datetime.datetime(2014, 11, 6, 0, 0),
#  datetime.datetime(2014, 11, 5, 0, 0),
#  datetime.datetime(2014, 11, 4, 0, 0),
#  datetime.datetime(2014, 11, 3, 0, 0),
#  datetime.datetime(2014, 11, 2, 0, 0),
#  datetime.datetime(2014, 11, 1, 0, 0),
#  datetime.datetime(2014, 10, 31, 0, 0),
#  datetime.datetime(2014, 10, 29, 0, 0),
#  datetime.datetime(2014, 10, 28, 0, 0),
#  datetime.datetime(2014, 10, 27, 0, 0),
#  datetime.datetime(2014, 10, 26, 0, 0),
#  datetime.datetime(2014, 10, 25, 0, 0),
#  datetime.datetime(2014, 10, 24, 0, 0),
#  datetime.datetime(2014, 10, 23, 0, 0),
#  datetime.datetime(2014, 10, 22, 0, 0),
#  datetime.datetime(2014, 10, 21, 0, 0),
#  datetime.datetime(2014, 10, 20, 0, 0),
#  datetime.datetime(2014, 10, 19, 0, 0),
#  datetime.datetime(2014, 10, 18, 0, 0),
#  datetime.datetime(2014, 10, 17, 0, 0),
#  datetime.datetime(2014, 10, 16, 0, 0),
#  datetime.datetime(2014, 10, 15, 0, 0),
#  datetime.datetime(2014, 10, 14, 0, 0),
#  datetime.datetime(2014, 10, 13, 0, 0),
#  datetime.datetime(2014, 10, 12, 0, 0),
#  datetime.datetime(2014, 10, 11, 0, 0),
#  datetime.datetime(2014, 10, 10, 0, 0),
#  datetime.datetime(2014, 10, 9, 0, 0),
#  datetime.datetime(2014, 10, 8, 0, 0),
#  datetime.datetime(2014, 10, 7, 0, 0),
#  datetime.datetime(2014, 10, 6, 0, 0),
#  datetime.datetime(2014, 10, 5, 0, 0),
#  datetime.datetime(2014, 10, 4, 0, 0),
#  datetime.datetime(2014, 10, 3, 0, 0),
#  datetime.datetime(2014, 10, 2, 0, 0),
#  datetime.datetime(2014, 10, 1, 0, 0),
#  datetime.datetime(2014, 9, 30, 0, 0),
#  datetime.datetime(2014, 9, 29, 0, 0),
#  datetime.datetime(2014, 9, 28, 0, 0),
#  datetime.datetime(2014, 9, 27, 0, 0),
#  datetime.datetime(2014, 9, 26, 0, 0),
#  datetime.datetime(2014, 9, 25, 0, 0),
#  datetime.datetime(2014, 9, 24, 0, 0),
#  datetime.datetime(2014, 9, 23, 0, 0),
#  datetime.datetime(2014, 9, 22, 0, 0),
#  datetime.datetime(2014, 9, 21, 0, 0),
#  datetime.datetime(2014, 9, 20, 0, 0),
#  datetime.datetime(2014, 9, 19, 0, 0),
#  datetime.datetime(2014, 9, 18, 0, 0),
#  datetime.datetime(2014, 9, 17, 0, 0),
#  datetime.datetime(2014, 9, 16, 0, 0),
#  datetime.datetime(2014, 9, 15, 0, 0),
#  datetime.datetime(2014, 9, 14, 0, 0),
#  datetime.datetime(2014, 9, 13, 0, 0),
#  datetime.datetime(2014, 9, 12, 0, 0),
#  datetime.datetime(2014, 9, 11, 0, 0),
#  datetime.datetime(2014, 9, 10, 0, 0),
#  datetime.datetime(2014, 9, 9, 0, 0),
#  datetime.datetime(2014, 9, 8, 0, 0),
#  datetime.datetime(2014, 9, 7, 0, 0),
#  datetime.datetime(2014, 9, 6, 0, 0),
#  datetime.datetime(2014, 9, 5, 0, 0),
#  datetime.datetime(2014, 9, 4, 0, 0),
#  datetime.datetime(2014, 9, 3, 0, 0),
#  datetime.datetime(2014, 9, 2, 0, 0),
#  datetime.datetime(2014, 9, 1, 0, 0),
#  datetime.datetime(2014, 8, 31, 0, 0),
#  datetime.datetime(2014, 8, 30, 0, 0),
#  datetime.datetime(2014, 8, 29, 0, 0),
#  datetime.datetime(2014, 8, 28, 0, 0),
#  datetime.datetime(2014, 8, 27, 0, 0),
#  datetime.datetime(2014, 8, 26, 0, 0),
#  datetime.datetime(2014, 8, 25, 0, 0),
#  datetime.datetime(2014, 8, 24, 0, 0),
#  datetime.datetime(2014, 8, 23, 0, 0),
#  datetime.datetime(2014, 8, 22, 0, 0),
#  datetime.datetime(2014, 8, 21, 0, 0),
#  datetime.datetime(2014, 8, 20, 0, 0),
#  datetime.datetime(2014, 8, 19, 0, 0),
#  datetime.datetime(2014, 8, 18, 0, 0),
#  datetime.datetime(2014, 8, 17, 0, 0),
#  datetime.datetime(2014, 8, 16, 0, 0),
#  datetime.datetime(2014, 8, 15, 0, 0),
#  datetime.datetime(2014, 8, 14, 0, 0),
#  datetime.datetime(2014, 8, 13, 0, 0),
#  datetime.datetime(2014, 8, 12, 0, 0),
#  datetime.datetime(2014, 8, 11, 0, 0),
#  datetime.datetime(2014, 8, 10, 0, 0),
#  datetime.datetime(2014, 8, 9, 0, 0),
#  datetime.datetime(2014, 8, 8, 0, 0),
#  datetime.datetime(2014, 8, 7, 0, 0),
#  datetime.datetime(2014, 8, 6, 0, 0),
#  datetime.datetime(2014, 8, 5, 0, 0),
#  datetime.datetime(2014, 8, 4, 0, 0),
#  datetime.datetime(2014, 8, 3, 0, 0),
#  datetime.datetime(2014, 8, 2, 0, 0),
#  datetime.datetime(2014, 8, 1, 0, 0),
#  datetime.datetime(2014, 7, 31, 0, 0),
#  datetime.datetime(2014, 7, 30, 0, 0),
#  datetime.datetime(2014, 7, 29, 0, 0),
#  datetime.datetime(2014, 7, 28, 0, 0),
#  datetime.datetime(2014, 7, 27, 0, 0),
#  datetime.datetime(2014, 7, 26, 0, 0),
#  datetime.datetime(2014, 7, 25, 0, 0),
#  datetime.datetime(2014, 7, 24, 0, 0),
#  datetime.datetime(2014, 7, 23, 0, 0),
#  datetime.datetime(2014, 7, 22, 0, 0),
#  datetime.datetime(2014, 7, 21, 0, 0),
#  datetime.datetime(2014, 7, 20, 0, 0),
#  datetime.datetime(2014, 7, 19, 0, 0),
#  datetime.datetime(2014, 7, 18, 0, 0),
#  datetime.datetime(2014, 7, 17, 0, 0),
#  datetime.datetime(2014, 7, 16, 0, 0),
#  datetime.datetime(2014, 7, 15, 0, 0),
#  datetime.datetime(2014, 7, 14, 0, 0),
#  datetime.datetime(2014, 7, 13, 0, 0),
#  datetime.datetime(2014, 7, 12, 0, 0),
#  datetime.datetime(2014, 7, 11, 0, 0),
#  datetime.datetime(2014, 7, 10, 0, 0),
#  datetime.datetime(2014, 7, 9, 0, 0),
#  datetime.datetime(2014, 7, 8, 0, 0),
#  datetime.datetime(2014, 7, 7, 0, 0),
#  datetime.datetime(2014, 7, 6, 0, 0),
#  datetime.datetime(2014, 7, 5, 0, 0),
#  datetime.datetime(2014, 7, 4, 0, 0),
#  datetime.datetime(2014, 7, 3, 0, 0),
#  datetime.datetime(2014, 7, 2, 0, 0),
#  datetime.datetime(2014, 6, 30, 0, 0),
#  datetime.datetime(2014, 6, 29, 0, 0),
#  datetime.datetime(2014, 6, 28, 0, 0),
#  datetime.datetime(2014, 6, 27, 0, 0),
#  datetime.datetime(2014, 6, 26, 0, 0),
#  datetime.datetime(2014, 6, 25, 0, 0),
#  datetime.datetime(2014, 6, 24, 0, 0),
#  datetime.datetime(2014, 6, 23, 0, 0),
#  datetime.datetime(2014, 6, 22, 0, 0),
#  datetime.datetime(2014, 6, 21, 0, 0),
#  datetime.datetime(2014, 6, 20, 0, 0),
#  datetime.datetime(2014, 6, 19, 0, 0),
#  datetime.datetime(2014, 6, 18, 0, 0),
#  datetime.datetime(2014, 6, 17, 0, 0),
#  datetime.datetime(2014, 6, 16, 0, 0),
#  datetime.datetime(2014, 6, 15, 0, 0),
#  datetime.datetime(2014, 6, 14, 0, 0),
#  datetime.datetime(2014, 6, 13, 0, 0),
#  datetime.datetime(2014, 6, 12, 0, 0),
#  datetime.datetime(2014, 6, 11, 0, 0),
#  datetime.datetime(2014, 6, 10, 0, 0),
#  datetime.datetime(2014, 6, 9, 0, 0),
#  datetime.datetime(2014, 6, 8, 0, 0),
#  datetime.datetime(2014, 6, 7, 0, 0),
#  datetime.datetime(2014, 6, 6, 0, 0),
#  datetime.datetime(2014, 6, 5, 0, 0),
#  datetime.datetime(2014, 6, 4, 0, 0),
#  datetime.datetime(2014, 6, 3, 0, 0),
#  datetime.datetime(2014, 6, 2, 0, 0),
#  datetime.datetime(2014, 6, 1, 0, 0),
#  datetime.datetime(2014, 5, 31, 0, 0),
#  datetime.datetime(2014, 5, 30, 0, 0),
#  datetime.datetime(2014, 5, 29, 0, 0),
#  datetime.datetime(2014, 5, 28, 0, 0),
#  datetime.datetime(2014, 5, 27, 0, 0),
#  datetime.datetime(2014, 5, 26, 0, 0),
#  datetime.datetime(2014, 5, 25, 0, 0),
#  datetime.datetime(2014, 5, 24, 0, 0),
#  datetime.datetime(2014, 5, 23, 0, 0),
#  datetime.datetime(2014, 5, 22, 0, 0),
#  datetime.datetime(2014, 5, 21, 0, 0),
#  datetime.datetime(2014, 5, 20, 0, 0),
#  datetime.datetime(2014, 5, 19, 0, 0),
#  datetime.datetime(2014, 5, 18, 0, 0),
#  datetime.datetime(2014, 5, 17, 0, 0),
#  datetime.datetime(2014, 5, 16, 0, 0),
#  datetime.datetime(2014, 5, 15, 0, 0),
#  datetime.datetime(2014, 5, 14, 0, 0),
#  datetime.datetime(2014, 5, 13, 0, 0),
#  datetime.datetime(2014, 5, 12, 0, 0),
#  datetime.datetime(2014, 5, 11, 0, 0),
#  datetime.datetime(2014, 5, 10, 0, 0),
#  datetime.datetime(2014, 5, 9, 0, 0),
#  datetime.datetime(2014, 5, 8, 0, 0),
#  datetime.datetime(2014, 5, 7, 0, 0),
#  datetime.datetime(2014, 5, 6, 0, 0),
#  datetime.datetime(2014, 5, 5, 0, 0),
#  datetime.datetime(2014, 5, 4, 0, 0),
#  datetime.datetime(2014, 5, 2, 0, 0),
#  datetime.datetime(2014, 5, 1, 0, 0),
#  datetime.datetime(2014, 4, 30, 0, 0),
#  datetime.datetime(2014, 4, 29, 0, 0),
#  datetime.datetime(2014, 4, 28, 0, 0),
#  datetime.datetime(2014, 4, 27, 0, 0),
#  datetime.datetime(2014, 4, 26, 0, 0),
#  datetime.datetime(2014, 4, 25, 0, 0),
#  datetime.datetime(2014, 4, 24, 0, 0),
#  datetime.datetime(2014, 4, 23, 0, 0),
#  datetime.datetime(2014, 4, 22, 0, 0),
#  datetime.datetime(2014, 4, 21, 0, 0),
#  datetime.datetime(2014, 4, 20, 0, 0),
#  datetime.datetime(2014, 4, 19, 0, 0),
#  datetime.datetime(2014, 4, 18, 0, 0),
#  datetime.datetime(2014, 4, 17, 0, 0),
#  datetime.datetime(2014, 4, 16, 0, 0),
#  datetime.datetime(2014, 4, 15, 0, 0),
#  datetime.datetime(2014, 4, 14, 0, 0),
#  datetime.datetime(2014, 4, 13, 0, 0),
#  datetime.datetime(2014, 4, 12, 0, 0),
#  datetime.datetime(2014, 4, 11, 0, 0),
#  datetime.datetime(2014, 4, 10, 0, 0),
#  datetime.datetime(2014, 4, 9, 0, 0),
#  datetime.datetime(2014, 4, 8, 0, 0),
#  datetime.datetime(2014, 4, 7, 0, 0),
#  datetime.datetime(2014, 4, 6, 0, 0),
#  datetime.datetime(2014, 4, 5, 0, 0),
#  datetime.datetime(2014, 4, 4, 0, 0),
#  datetime.datetime(2014, 4, 3, 0, 0),
#  datetime.datetime(2014, 4, 2, 0, 0),
#  datetime.datetime(2014, 4, 1, 0, 0),
#  datetime.datetime(2014, 3, 31, 0, 0),
#  datetime.datetime(2014, 3, 30, 0, 0),
#  datetime.datetime(2014, 3, 29, 0, 0),
#  datetime.datetime(2014, 3, 28, 0, 0),
#  datetime.datetime(2014, 3, 27, 0, 0),
#  datetime.datetime(2014, 3, 26, 0, 0),
#  datetime.datetime(2014, 3, 25, 0, 0),
#  datetime.datetime(2014, 3, 24, 0, 0),
#  datetime.datetime(2014, 3, 23, 0, 0),
#  datetime.datetime(2014, 3, 22, 0, 0),
#  datetime.datetime(2014, 3, 21, 0, 0),
#  datetime.datetime(2014, 3, 20, 0, 0),
#  datetime.datetime(2014, 3, 19, 0, 0),
#  datetime.datetime(2014, 3, 18, 0, 0),
#  datetime.datetime(2014, 3, 17, 0, 0),
#  datetime.datetime(2014, 3, 16, 0, 0),
#  datetime.datetime(2014, 3, 14, 0, 0),
#  datetime.datetime(2014, 3, 13, 0, 0),
#  datetime.datetime(2014, 3, 12, 0, 0),
#  datetime.datetime(2014, 3, 11, 0, 0),
#  datetime.datetime(2014, 3, 10, 0, 0),
#  datetime.datetime(2014, 3, 9, 0, 0),
#  datetime.datetime(2014, 3, 8, 0, 0),
#  datetime.datetime(2014, 3, 7, 0, 0),
#  datetime.datetime(2014, 3, 6, 0, 0),
#  datetime.datetime(2014, 3, 5, 0, 0),
#  datetime.datetime(2014, 3, 4, 0, 0),
#  datetime.datetime(2014, 3, 3, 0, 0),
#  datetime.datetime(2014, 3, 2, 0, 0),
#  datetime.datetime(2014, 3, 1, 0, 0),
#  datetime.datetime(2014, 2, 28, 0, 0),
#  datetime.datetime(2014, 2, 27, 0, 0),
#  datetime.datetime(2014, 2, 26, 0, 0),
#  datetime.datetime(2014, 2, 25, 0, 0),
#  datetime.datetime(2014, 2, 24, 0, 0),
#  datetime.datetime(2014, 2, 23, 0, 0),
#  datetime.datetime(2014, 2, 22, 0, 0),
#  datetime.datetime(2014, 2, 21, 0, 0),
#  datetime.datetime(2014, 2, 20, 0, 0),
#  datetime.datetime(2014, 2, 19, 0, 0),
#  datetime.datetime(2014, 2, 18, 0, 0),
#  datetime.datetime(2014, 2, 17, 0, 0),
#  datetime.datetime(2014, 2, 16, 0, 0),
#  datetime.datetime(2014, 2, 15, 0, 0),
#  datetime.datetime(2014, 2, 14, 0, 0),
#  datetime.datetime(2014, 2, 13, 0, 0),
#  datetime.datetime(2014, 2, 12, 0, 0),
#  datetime.datetime(2014, 2, 11, 0, 0),
#  datetime.datetime(2014, 2, 10, 0, 0),
#  datetime.datetime(2014, 2, 9, 0, 0),
#  ...]

# %%
def get_gtfs_file(datetime, gtfs_lookup_df):
    
    for gtfs_file in gtfs_lookup_df.iterrows():
        
        from_raw = gtfs_file[1]['from_date']
        from_date = datetime.strptime(from_raw, '%Y-%m-%d')
        
        to_raw = gtfs_file[1]['to_date']
        to_date = datetime.strptime(to_raw, '%Y-%m-%d')
        
        if from_date <= datetime < to_date:
            
            return gtfs_file[1]['directory']
        
    return None

# %%
def build_df(clean_list, gtfs_lookup_df):
    
    """
    Input: 
        -List of clean, sorted files constrained by date
        -Dataframe of GTFS directory and their effective date ranges
    Output:
        DataFrame with
            -Timestamp of Data Date
            -ISO string of Data Date
            -String of FTP file name
            -String of local GTFS Data Location 
    """
    
    pre_df = []
    
    for item in clean_list:
        
        ftp_filename = 'sfmtaAVLRawData' + item.strftime('%m%d%Y') + '.csv'
        
        iso_string = item.strftime('%Y-%m-%d')
        
        time_stamp = item.timestamp()
        
        directory = get_gtfs_file(item, gtfs_lookup_df)
        
        pre_df.append([ftp_filename, iso_string, time_stamp, directory])
        
    df = pd.DataFrame(pre_df, columns=['ftp_filename', 'iso_string', 'time_stamp', 'gtfs_directory'])
    
    return df

# %%
gtfs_plz = pd.read_csv('data/gtfs_lookup.csv')

c = b[:10]

d = build_df(c, gtfs_plz)

d
# Out:
#                   ftp_filename  iso_string    time_stamp    gtfs_directory
# 0  sfmtaAVLRawData12052016.csv  2016-12-05  1.480925e+09  sfmta_2017-02-10
# 1  sfmtaAVLRawData12042016.csv  2016-12-04  1.480838e+09  sfmta_2017-02-10
# 2  sfmtaAVLRawData12032016.csv  2016-12-03  1.480752e+09  sfmta_2017-02-10
# 3  sfmtaAVLRawData11232016.csv  2016-11-23  1.479888e+09  sfmta_2017-02-10
# 4  sfmtaAVLRawData11222016.csv  2016-11-22  1.479802e+09  sfmta_2017-02-10
# 5  sfmtaAVLRawData11212016.csv  2016-11-21  1.479715e+09  sfmta_2017-02-10
# 6  sfmtaAVLRawData11202016.csv  2016-11-20  1.479629e+09  sfmta_2017-02-10
# 7  sfmtaAVLRawData11192016.csv  2016-11-19  1.479542e+09  sfmta_2017-02-10
# 8  sfmtaAVLRawData11182016.csv  2016-11-18  1.479456e+09  sfmta_2017-02-10
# 9  sfmtaAVLRawData11172016.csv  2016-11-17  1.479370e+09  sfmta_2017-02-10

# %%
def x_recent_days(num_days):
    
    """
    Input: Number of Days of Data Desired
    Output: DataFrame file, time and gtfs data
          
    MAX DAYS AVAILABLE: 1529
    """
    
    gtfs_lookup_df = pd.read_csv('data/gtfs_lookup.csv')
    
    files = get_data_list()

    cln_srted = clean_sort_file_list(files)
    
    selection = cln_srted[:num_days]
    
    df = build_df(selection, gtfs_lookup_df)
    
    return df

# %%
working_df = x_recent_days(20)

# %%
working_df
# Out:
#                    ftp_filename  iso_string    time_stamp    gtfs_directory
# 0   sfmtaAVLRawData12052016.csv  2016-12-05  1.480925e+09  sfmta_2017-02-10
# 1   sfmtaAVLRawData12042016.csv  2016-12-04  1.480838e+09  sfmta_2017-02-10
# 2   sfmtaAVLRawData12032016.csv  2016-12-03  1.480752e+09  sfmta_2017-02-10
# 3   sfmtaAVLRawData11232016.csv  2016-11-23  1.479888e+09  sfmta_2017-02-10
# 4   sfmtaAVLRawData11222016.csv  2016-11-22  1.479802e+09  sfmta_2017-02-10
# 5   sfmtaAVLRawData11212016.csv  2016-11-21  1.479715e+09  sfmta_2017-02-10
# 6   sfmtaAVLRawData11202016.csv  2016-11-20  1.479629e+09  sfmta_2017-02-10
# 7   sfmtaAVLRawData11192016.csv  2016-11-19  1.479542e+09  sfmta_2017-02-10
# 8   sfmtaAVLRawData11182016.csv  2016-11-18  1.479456e+09  sfmta_2017-02-10
# 9   sfmtaAVLRawData11172016.csv  2016-11-17  1.479370e+09  sfmta_2017-02-10
# 10  sfmtaAVLRawData11162016.csv  2016-11-16  1.479283e+09  sfmta_2017-02-10
# 11  sfmtaAVLRawData11152016.csv  2016-11-15  1.479197e+09  sfmta_2017-02-10
# 12  sfmtaAVLRawData11142016.csv  2016-11-14  1.479110e+09  sfmta_2017-02-10
# 13  sfmtaAVLRawData11132016.csv  2016-11-13  1.479024e+09  sfmta_2017-02-10
# 14  sfmtaAVLRawData11122016.csv  2016-11-12  1.478938e+09  sfmta_2017-02-10
# 15  sfmtaAVLRawData11112016.csv  2016-11-11  1.478851e+09  sfmta_2017-02-10
# 16  sfmtaAVLRawData11102016.csv  2016-11-10  1.478765e+09  sfmta_2017-02-10
# 17  sfmtaAVLRawData11092016.csv  2016-11-09  1.478678e+09  sfmta_2017-02-10
# 18  sfmtaAVLRawData11082016.csv  2016-11-08  1.478592e+09  sfmta_2017-02-10
# 19  sfmtaAVLRawData11072016.csv  2016-11-07  1.478506e+09  sfmta_2017-02-10
