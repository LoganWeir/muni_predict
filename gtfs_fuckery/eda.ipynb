# %%
import pandas as pd

# %%
# !ls google_transit/
# Out:
# SFMTA_Transit_Data_License_Agreement.txt
# agency.txt
# calendar.txt
# calendar_dates.txt
# fare_attributes.txt
# fare_rules.txt
# routes.txt
# shapes.txt
# stop_times.txt
# stops.txt
# trips.txt

# %%
trips = pd.read_csv('google_transit/trips.txt')
stop_time = pd.read_csv('google_transit/stop_times.txt')
stops = pd.read_csv('google_transit/stops.txt')
routes = pd.read_csv('google_transit/routes.txt')
shape = pd.read_csv('google_transit/shapes.txt')

# %%
trips.head()
# Out:
#    route_id  service_id  trip_id        trip_headsign  direction_id  block_id  \
# 0     12691           2  7779650  Geary + 33rd Avenue             0       115
# 1     12691           2  7779643  Geary + 33rd Avenue             0       107
# 2     12691           2  7779640  Geary + 33rd Avenue             0       111
# 3     12691           2  7779635  Geary + 33rd Avenue             0       110
# 4     12691           2  7779631  Geary + 33rd Avenue             0       109
#
#    shape_id
# 0    151759
# 1    151759
# 2    151759
# 3    151759
# 4    151759

# %%
stop_time[stop_time['trip_id'] == 7779156]
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence stop_headsign  \
# 0   7779156     08:39:00       08:39:00     4015              1
# 1   7779156     08:40:02       08:40:02     6294              2
# 2   7779156     08:41:21       08:41:21     6290              3
# 3   7779156     08:42:00       08:42:00     6314              4
# 4   7779156     08:43:11       08:43:11     6307              5
# 5   7779156     08:44:36       08:44:36     6302              6
# 6   7779156     08:45:45       08:45:45     6299              7
# 7   7779156     08:46:45       08:46:45     6316              8
# 8   7779156     08:48:00       08:48:00     6312              9
# 9   7779156     08:49:08       08:49:08     6315             10
# 10  7779156     08:50:05       08:50:05     6301             11
# 11  7779156     08:50:44       08:50:44     6304             12
# 12  7779156     08:51:26       08:51:26     6300             13
# ...

# %%
trips[trips['trip_id'] == 7779156]
# Out:
#      route_id  service_id  trip_id    trip_headsign  direction_id  block_id  \
# 574     12691           1  7779156  Presidio Avenue             0       126
#
#      shape_id
# 574    151757

# %%
routes[routes['route_id'] == 12691]
# Out:
#    route_id agency_id route_short_name route_long_name route_desc  route_type  \
# 0     12691     SFMTA                1      CALIFORNIA                      3
#
#   route_url route_color route_text_color
# 0

# %%
stops[stops['stop_id'] == 4015]
# Out:
#      stop_id  stop_code             stop_name stop_desc   stop_lat  \
# 782     4015      14015  Clay St & Drumm St              37.795436
#
#        stop_lon zone_id stop_url
# 782 -122.396819

# %%
stops[stops['stop_id'] == 3892]
# Out:
#      stop_id  stop_code                       stop_name stop_desc   stop_lat  \
# 705     3892      13892  California St & Presidio Ave              37.787265
#
#        stop_lon zone_id stop_url
# 705 -122.446965

# %%
routes.head()
# Out:
#    route_id agency_id route_short_name route_long_name route_desc  route_type  \
# 0     12691     SFMTA                1      CALIFORNIA                      3
# 1     12693     SFMTA                2  SUTTER/CLEMENT                      3
# 2     12694     SFMTA                3         JACKSON                      3
# 3     12695     SFMTA                5          FULTON                      3
# 4     12696     SFMTA               5R    FULTON RAPID                      3
#
#   route_url route_color route_text_color
# 0
# 1
# 2
# 3
# 4

# %%
shape.head()
# Out:
#    shape_id  shape_pt_lon  shape_pt_lat  shape_pt_sequence  \
# 0    151757   -122.396968     37.795436                  1
# 1    151757   -122.396784     37.795471                  2
# 2    151757   -122.396598     37.794593                  3
# 3    151757   -122.397809     37.794439                  4
# 4    151757   -122.398983     37.794289                  5
#
#    shape_dist_traveled
# 0                    0
# 1                   17
# 2                  116
# 3                  224
# 4                  329
