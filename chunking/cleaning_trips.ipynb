# %%
from datetime import datetime
import pandas as pd
from geopy import distance
import numpy as np

import random

import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

db = client['avl_pipeline_test']
start_coll = db['redux_starts']
trip_coll = db['redux_labeled_trips']
chnk_coll = db['chunk_info']
cln_coll = db['clean_trips']

# %%
samp_start = list(start_coll.aggregate([{'$sample':{'size':1}}]))[0]

# %%
samp_id = samp_start['trip_id_iso']

# %%
chnk_samp = chnk_coll.find_one()

# %%
for start in start_coll.find():
    
    trip_id = start['trip_id_iso']
    
    start_trips = list(trip_coll.find({'trip_id_iso': trip_id}))
    
    end_trips = list(trip_coll.find({'trip_id_iso': trip_id, "trip_end":1}))
    
    if not start_trips:
        
        print ("NOPE")
        
    elif not end_trips:
        
        print ("ALSO NOPE")
        
    else:
        
        cln_coll.insert_one(start)
        
        for doc in start_trips:
            
            cln_coll.insert_one(doc)
# Out:
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# ALSO NOPE
# ALSO NOPE
# ALSO NOPE
# NOPE
# NOPE
# ...

# %%
cln_coll.find({"trip_start": 1}).count()
# Out:
# 1332
