# %%
from datetime import datetime
import pandas as pd
from geopy import distance
import numpy as np

import pymongo
from pymongo import MongoClient

import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

# %%
client = MongoClient('localhost', 27017)

db = client['avl_pipeline_test']
in_coll = db['trips']
edge_coll = db['edges']
out_coll = db['edges_standardized']

# %%
# Optional - Clean the output collection!
out_coll.delete_many({});

# %%
def normalize_duration(duration, sequence):
    
    edge_deets = edge_coll.find_one({'sequence': sequence})
    
    return (duration - edge_deets['mean'])/edge_deets['std_dev']

# %%
for example in in_coll.find():

    trip_id = example['_id']

    edge_sequence = list(example['edges'].keys())

    for idx, edge_seq in enumerate(edge_sequence):

        edge_info = example['edges'][edge_seq]

        edge_details = {}

        edge_details['edge_id'] = trip_id + "_" + edge_seq

        edge_details['sequence'] = edge_seq

        edge_details['weekend'] = example['weekend']
        edge_details['rush_hour'] = example['rush_hour']
        edge_details['midday'] = example['midday']

#         normed_edge = normalize_duration(edge_info['edge_time'], edge_seq)

#         example['edges'][edge_seq]['normed_edge'] = normed_edge
        edge_details['standard_edge'] = edge_info['edge_time']


        if idx == 0:

            edge_details['first_prior'] = 0
            edge_details['second_prior'] = 0

        elif idx == 1:

            frstp_seq = edge_sequence[idx-1]        
            edge_details['first_prior'] = example['edges'][frstp_seq]['edge_time']

            edge_details['second_prior'] = 0

        else:

            frstp_seq = edge_sequence[idx-1]        
            edge_details['first_prior'] = example['edges'][frstp_seq]['edge_time']

            scndp_seq = edge_sequence[idx-2]        
            edge_details['second_prior'] = example['edges'][scndp_seq]['edge_time']

        out_coll.insert_one(edge_details)

# %%
out_coll.count()
# Out:
# 53561

# %%
edge_coll.find_one()
# Out:
# {'_id': ObjectId('5ae7b4ba3ad39e762bcbecfb'),
#  'sequence': '1',
#  'mean': 81.58061953931691,
#  'std_dev': 38.841898301128815}

# %%
list(out_coll.find())
# Out:
# [{'_id': ObjectId('5ae7cc6a3ad39e78321c4419'),
#   'edge_id': '7253717_2016-10-28_HKH3O_1',
#   'sequence': '1',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.1652694832501667,
#   'first_prior': 0,
#   'second_prior': 0},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441a'),
#   'edge_id': '7253717_2016-10-28_HKH3O_2',
#   'sequence': '2',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.06165484088422265,
#   'first_prior': 0.1652694832501667,
#   'second_prior': 0},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441b'),
#   'edge_id': '7253717_2016-10-28_HKH3O_3',
#   'sequence': '3',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.5429640499652788,
#   'first_prior': -0.06165484088422265,
#   'second_prior': 0.1652694832501667},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441c'),
#   'edge_id': '7253717_2016-10-28_HKH3O_4',
#   'sequence': '4',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.3012911771091698,
#   'first_prior': -0.5429640499652788,
#   'second_prior': -0.06165484088422265},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441d'),
#   'edge_id': '7253717_2016-10-28_HKH3O_5',
#   'sequence': '5',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.05959995780137577,
#   'first_prior': 0.3012911771091698,
#   'second_prior': -0.5429640499652788},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441e'),
#   'edge_id': '7253717_2016-10-28_HKH3O_6',
#   'sequence': '6',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.5232297302397801,
#   'first_prior': -0.05959995780137577,
#   'second_prior': 0.3012911771091698},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c441f'),
#   'edge_id': '7253717_2016-10-28_HKH3O_7',
#   'sequence': '7',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 1.4476969463525946,
#   'first_prior': -0.5232297302397801,
#   'second_prior': -0.05959995780137577},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4420'),
#   'edge_id': '7253717_2016-10-28_HKH3O_8',
#   'sequence': '8',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.04820671155998828,
#   'first_prior': 1.4476969463525946,
#   'second_prior': -0.5232297302397801},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4421'),
#   'edge_id': '7253717_2016-10-28_HKH3O_9',
#   'sequence': '9',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.6944148763537014,
#   'first_prior': -0.04820671155998828,
#   'second_prior': 1.4476969463525946},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4422'),
#   'edge_id': '7253717_2016-10-28_HKH3O_10',
#   'sequence': '10',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.4225055666688504,
#   'first_prior': -0.6944148763537014,
#   'second_prior': -0.04820671155998828},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4423'),
#   'edge_id': '7253717_2016-10-28_HKH3O_11',
#   'sequence': '11',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.10891723663292839,
#   'first_prior': -0.4225055666688504,
#   'second_prior': -0.6944148763537014},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4424'),
#   'edge_id': '7253717_2016-10-28_HKH3O_12',
#   'sequence': '12',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.21121876885099827,
#   'first_prior': 0.10891723663292839,
#   'second_prior': -0.4225055666688504},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4425'),
#   'edge_id': '7253717_2016-10-28_HKH3O_13',
#   'sequence': '13',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.17800763206118064,
#   'first_prior': -0.21121876885099827,
#   'second_prior': 0.10891723663292839},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4426'),
#   'edge_id': '7253717_2016-10-28_HKH3O_14',
#   'sequence': '14',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.19690930606787715,
#   'first_prior': -0.17800763206118064,
#   'second_prior': -0.21121876885099827},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4427'),
#   'edge_id': '7253717_2016-10-28_HKH3O_15',
#   'sequence': '15',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.4854443829307913,
#   'first_prior': -0.19690930606787715,
#   'second_prior': -0.17800763206118064},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4428'),
#   'edge_id': '7253717_2016-10-28_HKH3O_16',
#   'sequence': '16',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.21367125164059986,
#   'first_prior': -0.4854443829307913,
#   'second_prior': -0.19690930606787715},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4429'),
#   'edge_id': '7253717_2016-10-28_HKH3O_17',
#   'sequence': '17',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.4185675053690364,
#   'first_prior': 0.21367125164059986,
#   'second_prior': -0.4854443829307913},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442a'),
#   'edge_id': '7253717_2016-10-28_HKH3O_18',
#   'sequence': '18',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.7069030463321351,
#   'first_prior': -0.4185675053690364,
#   'second_prior': 0.21367125164059986},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442b'),
#   'edge_id': '7253717_2016-10-28_HKH3O_19',
#   'sequence': '19',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -1.0487819478578277,
#   'first_prior': 0.7069030463321351,
#   'second_prior': -0.4185675053690364},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442c'),
#   'edge_id': '7253717_2016-10-28_HKH3O_20',
#   'sequence': '20',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.18138005574794422,
#   'first_prior': -1.0487819478578277,
#   'second_prior': 0.7069030463321351},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442d'),
#   'edge_id': '7253717_2016-10-28_HKH3O_21',
#   'sequence': '21',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 1.5097079889669913,
#   'first_prior': -0.18138005574794422,
#   'second_prior': -1.0487819478578277},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442e'),
#   'edge_id': '7253717_2016-10-28_HKH3O_22',
#   'sequence': '22',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.27615895285546405,
#   'first_prior': 1.5097079889669913,
#   'second_prior': -0.18138005574794422},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c442f'),
#   'edge_id': '7253717_2016-10-28_HKH3O_23',
#   'sequence': '23',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.09856455922310035,
#   'first_prior': 0.27615895285546405,
#   'second_prior': 1.5097079889669913},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4430'),
#   'edge_id': '7253717_2016-10-28_HKH3O_24',
#   'sequence': '24',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.9101130558040813,
#   'first_prior': 0.09856455922310035,
#   'second_prior': 0.27615895285546405},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4431'),
#   'edge_id': '7253717_2016-10-28_HKH3O_25',
#   'sequence': '25',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -1.1427906805084485,
#   'first_prior': -0.9101130558040813,
#   'second_prior': 0.09856455922310035},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4432'),
#   'edge_id': '7253717_2016-10-28_HKH3O_26',
#   'sequence': '26',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.11108176147469946,
#   'first_prior': -1.1427906805084485,
#   'second_prior': -0.9101130558040813},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4433'),
#   'edge_id': '7253717_2016-10-28_HKH3O_27',
#   'sequence': '27',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -1.0365079068436547,
#   'first_prior': 0.11108176147469946,
#   'second_prior': -1.1427906805084485},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4434'),
#   'edge_id': '7253717_2016-10-28_HKH3O_28',
#   'sequence': '28',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.1360583359758135,
#   'first_prior': -1.0365079068436547,
#   'second_prior': 0.11108176147469946},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4435'),
#   'edge_id': '7253717_2016-10-28_HKH3O_29',
#   'sequence': '29',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.3826387058660821,
#   'first_prior': 0.1360583359758135,
#   'second_prior': -1.0365079068436547},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4436'),
#   'edge_id': '7253717_2016-10-28_HKH3O_30',
#   'sequence': '30',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.47787989023948185,
#   'first_prior': -0.3826387058660821,
#   'second_prior': 0.1360583359758135},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4437'),
#   'edge_id': '7253717_2016-10-28_HKH3O_31',
#   'sequence': '31',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.6042040124510095,
#   'first_prior': -0.47787989023948185,
#   'second_prior': -0.3826387058660821},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4438'),
#   'edge_id': '7253717_2016-10-28_HKH3O_32',
#   'sequence': '32',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.28464464635590786,
#   'first_prior': -0.6042040124510095,
#   'second_prior': -0.47787989023948185},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4439'),
#   'edge_id': '7253717_2016-10-28_HKH3O_33',
#   'sequence': '33',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.7177773902985418,
#   'first_prior': -0.28464464635590786,
#   'second_prior': -0.6042040124510095},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443a'),
#   'edge_id': '7253717_2016-10-28_HKH3O_34',
#   'sequence': '34',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.9240817441265294,
#   'first_prior': -0.7177773902985418,
#   'second_prior': -0.28464464635590786},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443b'),
#   'edge_id': '7253717_2016-10-28_HKH3O_35',
#   'sequence': '35',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.44279673133171965,
#   'first_prior': -0.9240817441265294,
#   'second_prior': -0.7177773902985418},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443c'),
#   'edge_id': '7253717_2016-10-28_HKH3O_36',
#   'sequence': '36',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.1701301428541311,
#   'first_prior': 0.44279673133171965,
#   'second_prior': -0.9240817441265294},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443d'),
#   'edge_id': '7253717_2016-10-28_HKH3O_37',
#   'sequence': '37',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -1.6248415176914672,
#   'first_prior': -0.1701301428541311,
#   'second_prior': 0.44279673133171965},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443e'),
#   'edge_id': '7253717_2016-10-28_HKH3O_38',
#   'sequence': '38',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.25710998201185825,
#   'first_prior': -1.6248415176914672,
#   'second_prior': -0.1701301428541311},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c443f'),
#   'edge_id': '7253717_2016-10-28_HKH3O_39',
#   'sequence': '39',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -1.0462084591430656,
#   'first_prior': -0.25710998201185825,
#   'second_prior': -1.6248415176914672},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4440'),
#   'edge_id': '7253717_2016-10-28_HKH3O_40',
#   'sequence': '40',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.16704017057024667,
#   'first_prior': -1.0462084591430656,
#   'second_prior': -0.25710998201185825},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4441'),
#   'edge_id': '7253717_2016-10-28_HKH3O_42',
#   'sequence': '42',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.06266345944111887,
#   'first_prior': 0.16704017057024667,
#   'second_prior': -1.0462084591430656},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4442'),
#   'edge_id': '7253717_2016-10-28_HKH3O_43',
#   'sequence': '43',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': 0.3904000845822398,
#   'first_prior': -0.06266345944111887,
#   'second_prior': 0.16704017057024667},
#  {'_id': ObjectId('5ae7cc6a3ad39e78321c4443'),
#   'edge_id': '7253717_2016-10-28_HKH3O_44',
#   'sequence': '44',
#   'weekend': 0,
#   'rush_hour': 0,
#   'midday': 0,
#   'normed_edge': -0.9103186126322772,
#   'first_prior': 0.3904000845822398,
#   'second_prior': -0.06266345944111887}]
