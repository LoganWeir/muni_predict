# %%
import pandas as pd

# %%
routes = pd.read_csv('data/gtfs/sfmta_2015-11-1/routes.txt')
trips = pd.read_csv('data/gtfs/sfmta_2015-11-1/trips.txt')
route_33_id = routes[routes['route_short_name'] == '33']['route_id'].values[0]
trips_33_dir0 = trips[(trips['route_id'] == route_33_id) & (trips['direction_id'] == 0)]

# %%
trips_33_dir0.head(2)
# Out:
#        route_id  service_id  trip_id     trip_headsign  direction_id  \
# 14199     10895           3  6709815  General Hospital             0
# 14200     10895           3  6709814  General Hospital             0
#
#        block_id  shape_id
# 14199      3304    133324
# 14200      3306    133324

# %%
shapes = pd.read_csv('data/gtfs/sfmta_2015-11-1/shapes.txt')

# %%
shapes.head()
# Out:
#    shape_id  shape_pt_lon  shape_pt_lat  shape_pt_sequence  \
# 0    133138   -122.446793     37.787256                  1
# 1    133138   -122.448467     37.787042                  2
# 2    133138   -122.450106     37.786828                  3
# 3    133138   -122.450221     37.786810                  4
# 4    133138   -122.451757     37.786614                  5
#
#    shape_dist_traveled
# 0                    0
# 1                  149
# 2                  295
# 3                  305
# 4                  442

# %%
stop_times = pd.read_csv('data/gtfs/sfmta_2015-11-1/stop_times.txt')

# %%
stop_times.head()
# Out:
#    trip_id arrival_time departure_time  stop_id  stop_sequence stop_headsign  \
# 0  6680994     07:09:00       07:09:00     4015              1
# 1  6680994     07:10:08       07:10:08     6294              2
# 2  6680994     07:11:21       07:11:21     6290              3
# 3  6680994     07:12:00       07:12:00     6314              4
# 4  6680994     07:12:47       07:12:47     6307              5
#
#   pickup_type drop_off_type shape_dist_traveled
# 0
# 1
# 2
# 3
# 4

# %%
stops_33 = stop_times[stop_times['trip_id'] == 6709815]
stops_33
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 451783  6709815     24:00:00       24:00:00     6293              1
# 451784  6709815     24:00:49       24:00:49     3879              2
# 451785  6709815     24:01:21       24:01:21     3852              3
# 451786  6709815     24:02:10       24:02:10     3644              4
# 451787  6709815     24:03:12       24:03:12     3645              5
# 451788  6709815     24:03:53       24:03:53     3649              6
# 451789  6709815     24:05:42       24:05:42     3642              7
# 451790  6709815     24:07:00       24:07:00     4224              8
# 451791  6709815     24:08:16       24:08:16     6479              9
# 451792  6709815     24:09:08       24:09:08     6481             10
# 451793  6709815     24:11:00       24:11:00     4963             11
# 451794  6709815     24:12:28       24:12:28     4947             12
# 451795  6709815     24:13:23       24:13:23     3665             13
# ...

# %%
stops = pd.read_csv('data/gtfs/sfmta_2015-11-1/stops.txt')

# %%
checking = stops[stops['stop_id'] == 7295]
checking
# Out:
#       stop_id                   stop_name stop_desc   stop_lat    stop_lon  \
# 4236     7295  Ashbury St & Frederick St             37.767305 -122.446473
#
#      zone_id stop_url
# 4236

# %% [markdown]
# ### Awesome! That's my stop!
#
# 2 stops that come before it?

# %%
checking.index[0]
# Out:
# 4236

# %%
targetstop_idx = stops_33[stops_33['stop_id'] == 7295].index[0]

# %%
stops_3_prime = stops_33.loc[(targetstop_idx - 2):targetstop_idx]
stops_3_ids = stops_3_prime['stop_id'].values

# %% [markdown]
# Cool. First, Second, and Final Node...
